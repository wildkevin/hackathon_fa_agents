# %% [markdown]
# # Multimodal Retrieval Augmented Generation with Content Understanding
#
# # Overview
#
# Azure AI Content Understanding provides a powerful solution for extracting data from diverse content types, while preserving semantic integrity and contextual relationships ensuring optimal performance in Retrieval Augmented Generation (RAG) applications.
#
# This sample demonstrates how to leverage Azure AI's Content Understanding capabilities to extract:
#
# - OCR and layout information from documents
# - Image description, summarization and classification
# - Audio transcription with speaker diarization from audio files
# - Shot detection, keyframe extraction, and audio transcription from videos
#
# This notebook illustrates how to extract content from unstructured multimodal data and apply it to Retrieval Augmented Generation (RAG). The resulting output can be converted to vector embeddings and indexed in Azure AI Search. When a user submits a query, Azure AI Search retrieves relevant chunks to generate a context-aware response.

# %% [markdown]
# # Load environment variables

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# Load and validate Azure AI Services configs
AZURE_AI_SERVICE_ENDPOINT = "https://ai-swethasundar6403ai189371267970.services.ai.azure.com/"
AZURE_AI_SERVICE_API_VERSION = os.getenv("AZURE_AI_SERVICE_API_VERSION") or "2025-05-01-preview"
AZURE_DOCUMENT_INTELLIGENCE_API_VERSION = os.getenv("AZURE_DOCUMENT_INTELLIGENCE_API_VERSION") or "2024-11-30"

# Load and validate Azure OpenAI configs
AZURE_OPENAI_ENDPOINT = "https://ai-swethasundar6403ai189371267970.openai.azure.com/"
AZURE_OPENAI_CHAT_DEPLOYMENT_NAME = "gpt-4.1"
AZURE_OPENAI_CHAT_API_VERSION = os.getenv("AZURE_OPENAI_CHAT_API_VERSION") or "2024-08-01-preview"
AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME = "text-embedding-ada-002"
AZURE_OPENAI_EMBEDDING_API_VERSION = os.getenv("AZURE_OPENAI_EMBEDDING_API_VERSION") or "2023-05-15"

# Load and validate Azure Search Services configs
AZURE_SEARCH_ENDPOINT = "https://agentichack-search.search.windows.net/"
AZURE_SEARCH_INDEX_NAME = "kevin-cu"

# %% [markdown]
# # Create custom analyzer

# %%
from langchain import hub
from langchain_openai import AzureChatOpenAI
from langchain_openai import AzureOpenAIEmbeddings
from langchain.schema import StrOutputParser
from langchain.schema.runnable import RunnablePassthrough
from langchain.text_splitter import MarkdownHeaderTextSplitter
from langchain.vectorstores.azuresearch import AzureSearch
from langchain_core.prompts import ChatPromptTemplate
from langchain.schema import Document
import requests
import json
import sys
import uuid
from pathlib import Path
from dotenv import find_dotenv, load_dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

# Add the parent directory to the path to use shared modules
parent_dir = Path(Path.cwd()).parent
sys.path.append(str(parent_dir))

# %% [markdown]
# ### Create analyzers with pre-defined schemas.
# Feel free to start with the provided sample data as a reference and experiment with your own data to explore its capabilities.

# %%
from pathlib import Path
from python.content_understanding_client import AzureContentUnderstandingClient
credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")

#set analyzer configs
analyzer_configs = [
    {
        "id": "financial-report-analyzer" + str(uuid.uuid4()),
        "template_path": "./analyzer_templates/financial_metrics.json",
        "location": Path("./data/tesco/TESCO - FY22.pdf"),
    }
]

# Create Content Understanding client
content_understanding_client = AzureContentUnderstandingClient(
    endpoint=AZURE_AI_SERVICE_ENDPOINT,
    api_version=AZURE_AI_SERVICE_API_VERSION,
    subscription_key="677G3ZH6bImljTOn8SIpUUPc4CCpfAlDahurgJuB9ohhPbpB3iDpJQQJ99BFACfhMk5XJ3w3AAAAACOG2TB5",
    token_provider=token_provider,
    x_ms_useragent="azure-ai-content-understanding-python/content_extraction", # This header is used for sample usage telemetry, please comment out this line if you want to opt out.
)

# Iterate through each config and create an analyzer
for analyzer in analyzer_configs:
    analyzer_id = analyzer["id"]
    template_path = analyzer["template_path"]

    try:
        
        # Create the analyzer using the content understanding client
        response = content_understanding_client.begin_create_analyzer(
            analyzer_id=analyzer_id,
            analyzer_template_path=template_path
        )
        result = content_understanding_client.poll_result(response)
        print(f"Successfully created analyzer: {analyzer_id}")
        
    except Exception as e:
        print(f"Failed to create analyzer: {analyzer_id}")
        print(f"Error: {e}")
# Out:
# Failed to create analyzer: financial-report-analyzer6a97c623-a507-4b9f-b1d9-9c5410a55263
# Error: 400 Client Error: Bad Request for url: https://ai-swethasundar6403ai189371267970.cognitiveservices.azure.com/contentunderstanding/analyzers/financial-report-analyzer6a97c623-a507-4b9f-b1d9-9c5410a55263?api-version=2025-05-01-preview

# %% [markdown]
# ### Use created analyzers to extract multimodal content

# %%
#Iterate through each analyzer created and analyze content for each modality

analyzer_results =[]
extracted_markdown = []
analyzer_content = []
for analyzer in analyzer_configs:
    analyzer_id = "hackathon_financial"
    template_path = analyzer["template_path"]
    file_location = Path("./data/sample_finance.png")
    try:
           # Analyze content
            response = content_understanding_client.begin_analyze(analyzer_id, file_location)
            result = content_understanding_client.poll_result(response)
            analyzer_results.append({"id":analyzer_id, "result": result["result"]})
            analyzer_content.append({"id": analyzer_id, "content": result["result"]["contents"]})
                       
    except Exception as e:
            print(e)
            print("Error in creating analyzer. Please double-check your analysis settings.\nIf there is a conflict, you can delete the analyzer and then recreate it, or move to the next cell and use the existing analyzer.")

print("Analyzer Results:")
for analyzer_result in analyzer_results:
    print(f"Analyzer ID: {analyzer_result['id']}")
    print(json.dumps(analyzer_result["result"], indent=2))            

# Delete the analyzer if it is no longer needed
#content_understanding_client.delete_analyzer(ANALYZER_ID)
# Out:
# Analyzer Results:
# Analyzer ID: hackathon_financial
# {
#   "analyzerId": "hackathon_financial",
#   "apiVersion": "2025-05-01-preview",
#   "createdAt": "2025-07-07T17:20:53Z",
#   "warnings": [],
#   "contents": [
#     {
#       "markdown": "<!-- PageHeader=\"Strategic report\" -->\n<!-- PageHeader=\"Financial review\" -->\n\n\n# Group review of performance.\n\nGroup sales increased by +3.0% at constant rates, with growth\nacross all regions on top of exceptionally strong sales last year.\nRevenue increased by +6.4% at constant rates including fuel sales\ngrowth of +48.1% as customers travelled more following the easing\nof government restrictions. While two-year like-for-like\" fuel sales\ngrowth was negative at (6.4)%, this primarily reflects lower demand\nin the first half, with fuel sales ahead of pre-pandemic levels by the\nend of the year.\n\nGroup adjusted operating profit* grew by +58.9% at constant rates,\nreflecting the strong sales performance across the retail businesses,\na reduction in COVID-19 related costs and a return to profitability\nin Tesco Bank. These benefits were partially offset by inflationary\npressures in the cost base, particularly in distribution costs. Group\nstatutory operating profit, which includes adjusting items related to\nthe costs of historical shareholder litigation claims, grew by +65.5%.\n\nFinance income and finance costs reduced year-on-year primarily\ndue to fair value remeasurement gains related to the mark-to-\nmarket movement on inflation-linked swaps, which were a \u00a3123m\nbenefit this year compared to a \u00a3(214)m charge in the prior year.\nThe reduction in our share of profit from joint ventures and\nassociates was principally due to profit from Tesco Underwriting\n\n\n<figure>\n</figure>\n\n\nbeing recognised within Tesco Bank operating profit following its\nfull acquisition in May. The increase in tax this year primarily reflects\nhigher levels of both retail and Tesco Bank operating profit, in addition\nto the revaluation of deferred tax relating to the announced change\nin the UK corporation tax rate from 19% to 25%, effective 1 April 2023.\n\nOur adjusted diluted EPSl\u00f8 rose by +88.8%, reflecting the increase\nin retail and Tesco Bank operating profit and a reduction in net\nfinance costs. We have proposed a final dividend of 7.70 pence\nper ordinary share, taking the full-year dividend to 10.90 pence\nper ordinary share, an increase of 19.1% year-on-year.\n\nNet debtlt1.00 reduced by \u00a31.4bn year-on-year, primarily driven by\nstrong free cash flow generation. Retail free cash flow\" increased\nby \u00a30.9bn year-on-year due to higher retail operating profits, the\nelimination of UK pension contributions (following the \u00a32.5bn one-off\ncontribution last year from the Asia disposal proceeds) and a working\ncapital benefit from higher sales. These benefits were partly offset\nby an increase in capital expenditure. The Net debt/EBITDA ratio was\n2.5 times at the year end, compared to 3.3 times last year.\n\nFurther commentary on all of these metrics can be found below and\na full income statement can be found on page 116.\n\n\n<table>\n<tr>\n<th rowspan=\"2\">52 weeks ended 26 February 202221</th>\n<th rowspan=\"2\">FY 2021/22</th>\n<th rowspan=\"2\">FY0 2020/21</th>\n<th colspan=\"2\">Total change YoY</th>\n</tr>\n<tr>\n<th>Actual rate</th>\n<th>Constant rate</th>\n</tr>\n<tr>\n<td>Group sales (exc. VAT, exc. fuel)(d)</td>\n<td>\u00a354,768m</td>\n<td>\u00a353,445m</td>\n<td>2.5%</td>\n<td>3.0%</td>\n</tr>\n<tr>\n<td>Fuel</td>\n<td>\u00a36,576m</td>\n<td>\u00a34,442m</td>\n<td>48.1%</td>\n<td>48.1%</td>\n</tr>\n<tr>\n<td>Revenue (exc. VAT, inc. fuel)</td>\n<td>\u00a361,344m</td>\n<td>\u00a357,887m</td>\n<td>6.0%</td>\n<td>6.4%</td>\n</tr>\n<tr>\n<td>Adjusted operating profit **</td>\n<td>\u00a32,825m</td>\n<td>\u00a31,788m</td>\n<td>58.0%</td>\n<td>58.9%</td>\n</tr>\n<tr>\n<td>Adjusting items</td>\n<td>\u00a3(265)m</td>\n<td>\u00a3(241)m</td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td>Group statutory operating profit</td>\n<td>\u00a32,560m</td>\n<td>\u00a31,547m</td>\n<td>65.5%</td>\n<td></td>\n</tr>\n<tr>\n<td>Net finance costs</td>\n<td>\u00a3(542)m</td>\n<td>\u00a3(937)m</td ...
#       "fields": {
#         "Total_Assets": {
#           "type": "string"
#         },
#         "Current_Assets": {
#           "type": "string"
#         },
#         "Inventory": {
#           "type": "string"
#         },
#         "Cash": {
#           "type": "string"
#         },
#         "Marketable_Securities": {
#           "type": "string"
#         },
#         "Accounts_Receivable": {
#           "type": "string"
#         },
#         "Accounts_Payable": {
#           "type": "string"
#         },
#         "Total_Liabilities": {
#           "type": "string"
#         },
#         "Current_Liabilities": {
#           "type": "string"
#         },
#         "Total_Debt": {
#           "type": "string"
#         },
#         "Shareholders_Equity": {
#           "type": "string"
#         },
#         "Revenue_a_k_a_Sales": {
#           "type": "string",
#           "valueString": "\u00a361,344m"
#         },
#         "Cost_of_Goods_Sold_COGS": {
#           "type": "string"
#         },
#         "Operating_Income_EBIT": {
#           "type": "string",
#           "valueString": "\u00a32,825m"
#         },
#         "EBITDA": {
#           "type": "string"
#         },
#         "Net_Income": {
#           "type": "string",
#           "valueString": "\u00a31,523m"
#         },
#         "Operating_Expenses_and_sub_items_SG_A_Advertising_R_D": {
#           "type": "string"
#         },
#         "Interest_Expense": {
#           "type": "string"
#         },
#         "Interest_Income": {
#           "type": "string"
#         },
#         "Lease_Expense": {
#           "type": "string"
#         },
#         "Depreciation": {
#           "type": "string"
#         },
#         "Amortization": {
#           "type": "string"
#         },
#         "Capital_Expenditures_Capex": {
#           "type": "string",
#           "valueString": "\u00a31.1bn"
#         },
#         "Operating_Cash_Flow": {
#           "type": "string"
#         },
#         "Net_Patient_Revenue": {
#           "type": "string"
#         },
#         "Net_Operating_Income_NOI": {
#           "type": "string"
#         },
#         "Rental_Revenue": {
#           "type": "string"
#         },
#         "Order_Backlog": {
#           "type": "string"
#         },
#         "Work_in_Progress": {
#           "type": "string"
#         },
#         "Total_Contract_Value": {
#           "type": "string"
#         },
#         "Retention_Receivables": {
#           "type": "string"
#         },
#         "Contract_Revenue": {
#           "type": "string"
#         },
#         "Reserves_Added": {
#           "type": "string"
#         },
#         "Reserves_Extracted_Produced": {
#           "type": "string"
#         },
#         "Total_Production": {
#           "type": "string"
#         },
#         "Production_Transport_Costs": {
#           "type": "string"
#         },
#         "Barrels_Produced": {
#           "type": "string"
#         },
#         "Loan_Amount": {
#           "type": "string"
#         },
#         "Collateral_Value_Property_Value": {
#           "type": "string"
#         },
#         "Debt_Service_Principal_Interest_Payments": {
#           "type": "string"
#         },
#         "Annual_Admissions": {
#           "type": "string"
#         },
#         "Average_Number_of_Beds": {
#           "type": "string"
#         },
#         "Operating_Expenses_ex_Depreciation": {
#           "type": "string"
#         },
#         "Earning_Assets": {
#           "type": "string"
#         },
#         "Average_Earning_Assets": {
#           "type": "string"
#         },
#         "Loan_Loss_Provisions": {
#           "type": "string"
#         },
#         "Total_Loans": {
#           "type": "string"
#         },
#         "Leased_Space": {
#           "type": "string"
#         },
#         "Total_Available_Space": {
#           "type": "string"
#         },
#         "Average_Subscribers": {
#           "type": "string"
#         },
#         "Total_Service_Revenue": {
#           "type": "string"
#         },
#         "Subscribers_at_Start_End_of_Period": {
#           "type": "string"
#         },
#         "Customers_at_Start_End_of_Period": {
#           "type": "string"
#         },
#         "Annual_Recurring_Revenue_ARR": {
#           "type": "string"
#         },
#         "Number_of_Transactions": {
#           "type": "string"
#         },
#         "Foot_Traffic": {
#           "type": "string"
#         },
#         "Sales_for_Stores_Open_gt_1_Year": {
#           "type": "string"
#         },
#         "Physical_Inventory_Count": {
#           "type": "string"
#         },
#         "Recorded_Inventory": {
#           "type": "string"
#         },
#         "Number_of_Drug_Trials_Total_and_Successful": {
#           "type": "string"
#         },
#         "Sales_from_Patent_Protected_Drugs": {
#           "type": "string"
#         },
#         "Market_Value_of_Equity_MVE": {
#           "type": "string"
#         }
#       },
#       "kind": "document",
#       "startPageNumber": 1,
#       "endPageNumber": 1,
#       "unit": "pixel",
#       "pages": [
#         {
#           "pageNumber": 1,
#           "angle": 0.03283107,
#           "width": 906,
#           "height": 1258,
#           "spans": [
#             {
#               "offset": 0,
#               "length": 7735
#             }
#           ],
#           "words": [
#             {
#               "content": "Strategic",
#               "span": {
#                 "offset": 17,
#                 "length": 9
#               },
#               "confidence": 0.995,
#               "source": "D(1,686,0,737,0,737,11,686,11)"
#             },
#             {
#               "content": "report",
#               "span": {
#                 "offset": 27,
#                 "length": 6
#               },
#               "confidence": 0.996,
#               "source": "D(1,740,0,778,0,778,11,740,11)"
#             },
#             {
#               "content": "Financial",
#               "span": {
#                 "offset": 56,
#                 "length": 9
#               },
#               "confidence": 0.994,
#               "source": "D(1,75,51,149,51,149,70,75,70)"
#             },
#             {
#               "content": "review",
#               "span": {
#                 "offset": 66,
#                 "length": 6
#               },
#               "confidence": 0.998,
#               "source": "D(1,155,51,212,51,212,70,155,70)"
#             },
#             {
#               "content": "Group",
#               "span": {
#                 "offset": 82,
#                 "length": 5
#               },
#               "confidence": 0.997,
#               "source": "D(1,73,125,247,128,247,186,72,182)"
#             },
#             {
#               "content": "review",
#               "span": {
#                 "offset": 88,
#                 "length": 6
#               },
#               "confidence": 0.998,
#               "source": "D(1,73,192,254,191,254,244,73,245)"
#             },
#             {
#               "content": "of",
#               "span": {
#                 "offset": 95,
#                 "length": 2
#               },
#               "confidence": 0.995,
#               "source": "D(1,272,191,328,191,328,244,272,244)"
#             },
#             {
#               "content": "performance.",
#               "span": {
#                 "offset": 98,
#                 "length": 12
#               },
#               "confidence": 0.992,
#               "source": "D(1,73,261,444,260,444,311,74,319)"
#             },
#             {
#               "content": "Group",
#               "span": {
#                 "offset": 112,
#                 "length": 5
#               },
#               "confidence": 0.995,
#               "source": "D(1,75,339,109,339,109,354,75,354)"
#             },
#             {
#               "content": "sales",
#               "span": {
#                 "offset": 118,
#                 "length": 5
#               },
#               "confidence": 0.841,
#               "source": "D(1,112,339,140,339,140,354,112,354)"
#             },
#             {
#               "content": "increased",
#               "span": {
#                 "offset": 124,
#                 "length": 9
#               },
#               "confidence": 0.977,
#               "source": "D(1,147,339,200,339,200,354,147,354)"
#             },
#             {
#               "content": "by",
#               "span": {
#                 "offset": 134,
#                 "length": 2
#               },
#               "confidence": 0.996,
#               "source": "D(1,203,339,216,339,216,354,203,354)"
#             },
#             {
#               "content": "+3.0%",
#               "span": {
#                 "offset": 137,
#                 "length": 5
#               },
#               "confidence": 0.992,
#               "source": "D(1,219,339,253,339,253,354,219,354)"
#             },
#             {
#               "content": "at",
#               "span": {
#                 "offset": 143,
#                 "length": 2
#               },
#               "confidence": 0.994,
#               "source": "D(1,256,339,266,339,266,355,256,354)"
#             },
#             {
#               "content": "constant",
#               "span": {
#                 "offset": 146,
#                 "length": 8
#               },
#               "confidence": 0.995,
#               "source": "D(1,269,339,315,339,315,355,269,355)"
#             },
#             {
#               "content": "rates,",
#               "span": {
#                 "offset": 155,
#                 "length": 6
#               },
#               "confidence": 0.992,
#               "source": "D(1,318,339,350,339,350,354,318,355)"
#             },
#             {
#               "content": "with",
#               "span": {
#                 "offset": 162,
#                 "length": 4
#               },
#               "confidence": 0.992,
#               "source": "D(1,353,339,375,339,375,355,353,354)"
#             },
#             {
#               "content": "growth",
#               "span": {
#                 "offset": 167,
#                 "length": 6
#               },
#               "confidence": 0.995,
#               "source": "D(1,378,339,418,339,418,355,378,355)"
#             },
#             {
#               "content": "across",
#               "span": {
#                 "offset": 174,
#                 "length": 6
#               },
#               "confidence": 0.992,
#               "source": "D(1,75,355,110,355,110,369,75,369)"
#             },
#             {
#               "content": "all",
#               "span": {
#                 "offset": 181,
#                 "length": 3
#               },
#               "confidence": 0.992,
#               "source": "D(1,112,355,125,355,125,369,112,369)"
#             },
#             {
#               "content": "regions",
#               "span": {
#                 "offset": 185,
#                 "length": 7
#               },
#               "confidence": 0.993,
#               "source": "D(1,128,355,166,355,166,369,129,369)"
#             },
#             {
#               "content": "on",
#               "span": {
#                 "offset": 193,
#                 "length": 2
#               },
#               "confidence": 0.996,
#               "source": "D(1,169,355,183,355,183,370,169,370)"
#             },
#             {
#               "content": "top",
#               "span": {
#                 "offset": 196,
#                 "length": 3
#               },
#               "confidence": 0.996,
#               "source": "D(1,186,355,204,355,204,370,186,370)"
#             },
#             {
#               "content": "of",
#               "span": {
#                 "offset": 200,
#                 "length": 2
#               },
#               "confidence": 0.995,
#               "source": "D(1,206,355,218,355,218,370,206,370)"
#             },
#             {
#               "content": "exceptionally",
#               "span": {
#                 "offset": 203,
#                 "length": 13
#               },
#               "confidence": 0.989,
#               "source": "D(1,221,355,290,355,290,370,221,370)"
#             },
#             {
#               "content": "strong",
#               "span": {
#                 "offset": 217,
#                 "length": 6
#               },
#               "confidence": 0.995,
#               "source": "D(1,293,355,327,355,327,370,293,370)"
#             },
#             {
#               "content": "sales",
#               "span": {
#                 "offset": 224,
#                 "length": 5
#               },
#               "confidence": 0.995,
#               "source": "D(1,330,355,357,355,357,370,330,370)"
#             },
#             {
#               "content": "last",
#               "span": {
#                 "offset": 230,
#                 "length": 4
#               },
#               "confidence": 0.992,
#               "source": "D(1,360,355,377,355,377,370,360,370)"
#             },
#             {
#               "content": "year.",
#               "span": {
#                 "offset": 235,
#                 "length": 5
#               },
#               "confidence": 0.992,
#               "source": "D(1,380,355,408,355,408,369,380,370)"
#             },
#             {
#               "content": "Revenue",
#               "span": {
#                 "offset": 241,
#                 "length": 7
#               },
#               "confidence": 0.992,
#               "source": "D(1,75,369,119,369,119,384,75,384)"
#             },
#             {
#               "content": "increased",
#               "span": {
#                 "offset": 249,
#                 "length": 9
#               },
#               "confidence": 0.992,
#               "source": "D(1,122,369,175,369,175,384,122,384)"
#             },
#             {
#               "content": "by",
#               "span": {
#                 "offset": 259,
#                 "length": 2
#               },
#               "confidence": 0.981,
#               "source": "D(1,178,369,191,369,191,384,178,384)"
#             },
#             {
#               "content": "+6.4%",
#               "span": {
#                 "offset": 262,
#                 "length": 5
#               },
#               "confidence": 0.992,
#               "source": "D(1,193,369,228,369,228,384,194,384)"
#             },
#             {
#               "content": "at",
#               "span": {
#                 "offset": 268,
#                 "length": 2
#               },
#               "confidence": 0.993,
#               "source": "D(1,231,369,241,369,241,384,231,384)"
#             },
#             {
#               "content": "constant",
#               "span": {
#                 "offset": 271,
#                 "length": 8
#               },
#               "confidence": 0.993,
#               "source": "D(1,244,369,290,369,290,384,244,384)"
#             },
#             {
#               "content": "rates",
#               "span": {
#                 "offset": 280,
#                 "length": 5
#               },
#               "confidence": 0.995,
#               "source": "D(1,293,369,320,369,320,384,293,384)"
#             },
#             {
#               "content": "including",
#               "span": {
#                 "offset": 286,
#                 "length": 9
#               },
#               "confidence": 0.99,
#               "source": "D(1,323,369,372,369,372,384,322,384)"
#             },
#             {
#               "content": "fuel",
#               "span": {
#                 "offset": 296,
#                 "length": 4
#               },
#               "confidence": 0.992,
#               "source": "D(1,375,369,394,370,394,384,375,384)"
#             },
#             {
#               "content": "sales",
#               "span": {
#                 "offset": 301,
#                 "length": 5
#               },
#               "confidence": 0.996,
#               "source": "D(1,397,370,425,370,425,384,397,384)"
#             },
#             {
#               "content": "growth",
#               "span": {
#                 "offset": 307,
#                 "length": 6
#               },
#               "confidence": 0.998,
#               "source": "D(1,75,384,112,384,112,398,75,399)"
#             },
#             {
#               "content": "of",
#               "span": {
#                 "offset": 314,
#                 "length": 2
#               },
#               "confidence": 0.997,
#               "source": "D(1,115,384,125,384,125,398,115,398)"
#             },
#             {
#               "content": "+48.1%",
#               "span": {
#                 "offset": 317,
#                 "length": 6
#               },
#               "confidence": 0.998,
#               "source": "D(1,128,384,166,384,166,398,128,398)"
#             },
#             {
#               "content": "as",
#               "span": {
#                 "offset": 324,
#                 "length": 2
#               },
#               "confidence": 0.998,
#               "source": "D(1,169,384,180,384,180,398,169,398)"
#             },
#             {
#               "content": "customers",
#               "span": {
#                 "offset": 327,
#                 "length": 9
#               },
#               "confidence": 0.995,
#               "source": "D(1,183,384,238,384,238,398,183,398)"
#             },
#             {
#               "content": "travelled",
#               "span": {
#                 "offset": 337,
#                 "length": 9
#               },
#               "confidence": 0.995,
#               "source": "D(1,241,384,286,384,286,398,241,398)"
#             },
#             {
#               "content": "more",
#               "span": {
#                 "offset": 347,
#                 "length": 4
#               },
#               "confidence": 0.992,
#               "source": "D(1,289,384,317,384,317,399,289,398)"
#             },
#             {
#               "content": "following",
#               "span": {
#                 "offset": 352,
#                 "length": 9
#               },
#               "confidence": 0.995,
#               "source": "D(1,320,384,367,384,367,399,320,399)"
#             },
#             {
#               "content": "the",
#               "span": {
#                 "offset": 362,
#                 "length": 3
#               },
#               "confidence": 0.999,
#               "source": "D(1,370,384,388,384,388,399,370,399)"
#             },
#             {
#               "content": "easing",
#               "span": {
#                 "offset": 366,
#                 "length": 6
#               },
#               "confidence": 0.997,
#               "source": "D(1,391,384,426,384,426,399,391,399)"
#             },
#             {
#               "content": "of",
#               "span": {
#                 "offset": 373,
#                 "length": 2
#               },
#               "confidence": 0.992,
#               "source": "D(1,75,399,86,399,86,413,75,414)"
#             },
#             {
#               "content": "government",
#               "span": {
#                 "offset": 376,
#                 "length": 10
#               },
#               "confidence": 0.992,
#               "source": "D(1,88,399,152,399,152,413,88,413)"
#             },
#             {
#               "content": "restrictions.",
#               "span": {
#                 "offset": 387,
#                 "length": 13
#               },
#               "confidence": 0.992,
#               "source": "D(1,155,399,221,399,221,413,155,413)"
#             },
#             {
#               "content": "While",
#               "span": {
#                 "offset": 401,
#                 "length": 5
#               },
#               "confidence": 0.997,
#               "source": "D(1,224,399,253,399,253,413,224,413)"
#             },
#             {
#               "content": "two-year",
#               "span": {
#                 "offset": 407,
#                 "length": 8
#               },
#               "confidence": 0.992,
#               "source": "D(1,256,399,302,398,302,413,256,413)"
#             },
#             {
#               "content": "like-for-like\"",
#               "span": {
#                 "offset": 416,
#                 "length": 14
#               },
#               "confidence": 0.576,
#               "source": "D(1,305,398,377,398,377,413,305,413)"
#             },
#             {
#               "content": "fuel",
#               "span": {
#                 "offset": 431,
#                 "length": 4
#               },
#               "confidence": 0.994,
#               "source": "D(1,380,398,399,398,399,413,380,413)"
#             },
#             {
#               "content": "sales",
#               "span": {
#                 "offset": 436,
#                 "length": 5
#               },
#               "confidence": 0.997,
#               "source": "D(1,402,398,430,399,430,413,402,413)"
#             },
#             {
#               "content": "growth",
#               "span": {
#                 "offset": 442,
#                 "length": 6
#               },
#               "confidence": 0.993,
#               "source": "D(1,75,414,111,414,111,429,75,429)"
#             },
#             {
#               "content": "was",
#               "span": {
#                 "offset": 449,
#                 "length": 3
#               },
#               "confidence": 0.997,
#               "source": "D(1,114,414,134,414,134,429,114,429)"
#             },
#             {
#               "content": "negative",
#               "span": {
#                 "offset": 453,
#                 "length": 8
#               },
#               "confidence": 0.996,
#               "source": "D(1,137,414,182,414,182,429,137,429)"
#             },
#             {
#               "content": "at",
#               "span": {
#                 "offset": 462,
#                 "length": 2
#               },
#               "confidence": 0.992,
#               "source": "D(1,185,414,196,414,196,429,185,429)"
#             },
#             {
#               "content": "(6.4)%,",
#               "span": {
#                 "offset": 465,
#                 "length": 7
#               },
#               "confidence": 0.977,
#               "source": "D(1,199,414,236,414,236,429,199,429)"
#             },
#             {
#               "content": "this",
#               "span": {
#                 "offset": 473,
#                 "length": 4
#               },
#               "confidence": 0.993,
#               "source": "D(1,239,414,259,413,259,429,239,429)"
#             },
#             {
#               "content": "primarily",
#               "span": {
#                 "offset": 478,
#                 "length": 9
#               },
#               "confidence": 0.992,
#               "source": "D(1,262,413,306,413,306,428,262,429)"
#             },
#             {
#               "content": "reflects",
#               "span": {
#                 "offset": 488,
#                 "length": 8
#               },
#               "confidence": 0.992,
#               "source": "D(1,309,413,349,413,349,428,309,428)"
#             },
#             {
#               "content": "lower",
#               "span": {
#                 "offset": 497,
#                 "length": 5
#               },
#               "confidence": 0.995,
#               "source": "D(1,352,413,383,414,383,428,352,428)"
#             },
#             {
#               "content": "demand",
#               "span": {
#                 "offset": 503,
#                 "length": 6
#               },
#               "confidence": 0.993,
#               "source": "D(1,386,414,431,414,431,428,386,428)"
#             },
#             {
#               "content": "in",
#               "span": {
#                 "offset": 510,
#                 "length": 2
#               },
#               "confidence": 0.995,
#               "source": "D(1,75,428,83,428,83,443,75,443)"
#             },
#             {
#               "content": "the",
#               "span": {
#                 "offset": 513,
#                 "length": 3
#               },
#               "confidence": 0.994,
#               "source": "D(1,86,428,104,428,104,443,86,443)"
#             },
#             {
#               "content": "first",
#               "span": {
#                 "offset": 517,
#                 "length": 5
#               },
#               "confidence": 0.993,
#               "source": "D(1,107,428,128,428,128,443,107,443)"
#             },
#             {
#               "content": "half,",
#               "span": {
#                 "offset": 523,
#                 "length": 5
#               },
#               "confidence": 0.977,
#               "source": "D(1,131,428,156,428,156,443,131,443)"
#             },
#             {
#               "content": "with",
#               "span": {
#                 "offset": 529,
#                 "length": 4
#               },
#               "confidence": 0.992,
#               "source": "D(1,159,428,181,428,181,443,159,443)"
#             },
#             {
#               "content": "fuel",
#               "span": {
#                 "offset": 534,
#                 "length": 4
#               },
#               "confidence": 0.992,
#               "source": "D(1,184,428,204,428,204,444,184,443)"
#             },
#             {
#               "content": "sales",
#               "span": {
#                 "offset": 539,
#                 "length": 5
#               },
#               "confidence": 0.995,
#               "source": "D(1,207,428,234,428,234,444,207,444)"
#             },
#             {
#               "content": "ahead",
#               "span": {
#                 "offset": 545,
#                 "length": 5
#               },
#               "confidence": 0.994,
#               "source": "D(1,237,428,269,428,269,444,237,444)"
#             },
#             {
#               "content": "of",
#               "span": {
#                 "offset": 551,
#                 "length": 2
#               },
#               "confidence": 0.992,
#               "source": "D(1,272,428,281,428,281,444,272,444)"
#             },
#             {
#               "content": "pre-pandemic",
#               "span": {
#                 "offset": 554,
#                 "length": 12
#               },
#               "confidence": 0.989,
#               "source": "D(1,284,428,362,428,362,444,284,444)"
#             },
#             {
#               "content": "levels",
#               "span": {
#                 "offset": 567,
#                 "length": 6
#               },
#               "confidence": 0.993,
#               "source": "D(1,366,428,395,428,395,444,366,444)"
#             },
#             {
#               "content": "by",
#               "span": {
#                 "offset": 574,
#                 "length": 2
#               },
#               "confidence": 0.999,
#               "source": "D(1,398,428,409,428,408,444,398,444)"
#             },
#             {
#               "content": "the",
#               "span": {
#                 "offset": 577,
#                 "length": 3
#               },
#               "confidence": 0.996,
#               "source": "D(1,412,428,432,428,432,443,411,444)"
#             },
#             {
#               "content": "end",
#               "span": {
#                 "offset": 581,
#                 "length": 3
#               },
#               "confidence": 0.997,
#               "source": "D(1,75,444,96,444,96,458,75,458)"
#             },
#             {
#               "content": "of",
#               "span": {
#                 "offset": 585,
#                 "length": 2
#               },
#               "confidence": 0.997,
#               "source": "D(1,99,444,110,444,110,458,99,458)"
#             },
#             {
#               "content": "the",
#               "span": {
#                 "offset": 588,
#                 "length": 3
#               },
#               "confidence": 0.999,
#               "source": "D(1,113,444,131,444,131,458,113,458)"
#             },
#             {
#               "content": "year.",
#               "span": {
#                 "offset": 592,
#                 "length": 5
#               },
#               "confidence": 0.992,
#               "source": "D(1,133,444,160,444,160,458,133,458)"
#             },
#             {
#               "content": "Group",
#               "span": {
#                 "offset": 599,
#                 "length": 5
#               },
#               "confidence": 0.995,
#               "source": "D(1,75,472,108,472,108,487,75,487)"
#             },
#             {
#               "content": "adjusted",
#               "span": {
#                 "offset": 605,
#                 "length": 8
#               },
#               "confidence": 0.992,
#               "source": "D(1,111,472,158,472,158,488,111,488)"
#             },
#             {
#               "content": "operating",
#               "span": {
#                 "offset": 614,
#                 "length": 9
#               },
#               "confidence": 0.992,
#               "source": "D(1,161,472,211,472,211,488,161,488)"
#             },
#             {
#               "content": "profit*",
#               "span": {
#                 "offset": 624,
#                 "length": 7
#               },
#               "confidence": 0.639,
#               "source": "D(1,214,472,250,472,250,488,214,488)"
#             },
#             {
#               "content": "grew",
#               "span": {
#                 "offset": 632,
#                 "length": 4
#               },
#               "confidence": 0.99,
#               "source": "D(1,253,472,278,472,278,488,253,488)"
#             },
#             {
#               "content": "by",
#               "span": {
#                 "offset": 637,
#                 "length": 2
#               },
#               "confidence": 0.996,
#               "source": "D(1,281,472,295,472,295,488,281,488)"
#             },
#             {
#               "content": "+58.9%",
#               "span": {
#                 "offset": 640,
#                 "length": 6
#               },
#               "confidence": 0.992,
#               "source": "D(1,298,472,337,472,337,488,298,488)"
#             },
#             {
#               "content": "at",
#               "span": {
#                 "offset": 647,
#                 "length": 2
#               },
#               "confidence": 0.998,
#               "source": "D(1,340,472,350,472,350,488,340,488)"
#             },
#             {
#               "content": "constant",
#               "span": {
#                 "offset": 650,
#                 "length": 8
#               },
#               "confidence": 0.993,
#               "source": "D(1,353,472,399,472,399,487,353,488)"
#             },
#             {
#               "content": "rates,",
#               "span": {
#                 "offset": 659,
#                 "length": 6
#               },
#               "confidence": 0.973,
#               "source": "D(1,402,472,435,472,435,487,402,487)"
#             },
#             {
#               "content": "reflecting",
#               "span": {
#                 "offset": 666,
#                 "length": 10
#               },
#               "confidence": 0.992,
#               "source": "D(1,75,488,125,488,125,502,75,502)"
#             },
#             {
#               "content": "the",
#               "span": {
#                 "offset": 677,
#                 "length": 3
#               },
#               "confidence": 0.997,
#               "source": "D(1,128,488,147,488,147,502,128,502)"
#             },
#             {
#               "content": "strong",
#               "span": {
#                 "offset": 681,
#                 "length": 6
#               },
#               "confidence": 0.996,
#               "source": "D(1,150,488,183,488,183,502,150,502)"
#             },
#             {
#               "content": "sales",
#               "span": {
#                 "offset": 688,
#                 "length": 5
#               },
#               "confidence": 0.996,
#               "source": "D(1,186,488,211,488,211,502,186,502)"
#             },
#             {
#               "content": "performance",
#               "span": {
#                 "offset": 694,
#                 "length": 11
#               },
#               "confidence": 0.995,
#               "source": "D(1,214,488,286,488,286,502,214,502)"
#             },
#             {
#               "content": "across",
#               "span": {
#                 "offset": 706,
#                 "length": 6
#               },
#               "confidence": 0.994,
#               "source": "D(1,289,488,324,488,324,502,289,502)"
#             },
#             {
#               "content": "the",
#               "span": {
#                 "offset": 713,
#                 "length": 3
#               },
#               "confidence": 0.998,
#               "source": "D(1,327,488,343,488,343,502,327,502)"
#             },
#             {
#               "content": "retail",
#               "span": {
#                 "offset": 717,
#                 "length": 6
#               },
#               "confidence": 0.992,
#               "source": "D(1,346,488,373,488,373,502,346,502)"
#             },
#             {
#               "content": "businesses,",
#               "span": {
#                 "offset": 724,
#                 "length": 11
#               },
#               "confidence": 0.936,
#               "source": "D(1,376,488,440,488,439,502,376,502)"
#             },
#             {
#               "content": "a",
#               "span": {
#                 "offset": 736,
#                 "length": 1
#               },
#               "confidence": 0.977,
#               "source": "D(1,75,502,80,502,80,517,75,517)"
#             },
#             {
#               "content": "reduction",
#               "span": {
#                 "offset": 738,
#                 "length": 9
#               },
#               "confidence": 0.989,
#               "source": "D(1,83,502,134,502,134,517,83,517)"
#             },
#             {
#               "content": "in",
#               "span": {
#                 "offset": 748,
#                 "length": 2
#               },
#               "confidence": 0.994,
#               "source": "D(1,137,502,149,502,149,517,137,517)"
#             },
#             {
#               "content": "COVID-19",
#               "span": {
#                 "offset": 751,
#                 "length": 8
#               },
#               "confidence": 0.992,
#               "source": "D(1,152,502,199,502,199,517,152,517)"
#             },
#             {
#               "content": "related",
#               "span": {
#                 "offset": 760,
#                 "length": 7
#               },
#               "confidence": 0.994,
#               "source": "D(1,202,502,242,502,242,517,202,517)"
#             },
#             {
#               "content": "costs",
#               "span": {
#                 "offset": 768,
#                 "length": 5
#               },
#               "confidence": 0.994,
#               "source": "D(1,245,502,274,502,274,517,245,517)"
#             },
#             {
#               "content": "and",
#               "span": {
#                 "offset": 774,
#                 "length": 3
#               },
#               "confidence": 0.993,
#               "source": "D(1,277,502,296,502,296,517,277,517)"
#             },
#             {
#               "content": "a",
#               "span": {
#                 "offset": 778,
#                 "length": 1
#               },
#               "confidence": 0.994,
#               "source": "D(1,300,502,304,502,304,517,300,517)"
#             },
#             {
#               "content": "return",
#               "span": {
#                 "offset": 780,
#                 "length": 6
#               },
#               "confidence": 0.992,
#               "source": "D(1,307,502,343,503,343,517,307,517)"
#             },
#             {
#               "content": "to",
#               "span": {
#                 "offset": 787,
#                 "length": 2
#               },
#               "confidence": 0.997,
#               "source": "D(1,346,503,357,503,357,517,345,517)"
#             },
#             {
#               "content": "profitability",
#               "span": {
#                 "offset": 790,
#                 "length": 13
#               },
#               "confidence": 0.991,
#               "source": "D(1,360,503,422,503,422,518,360,517)"
#             },
#             {
#               "content": "in",
#               "span": {
#                 "offset": 804,
#                 "length": 2
#               },
#               "confidence": 0.993,
#               "source": "D(1,75,517,85,517,85,532,75,532)"
#             },
#             {
#               "content": "Tesco",
#               "span": {
#                 "offset": 807,
#                 "length": 5
#               },
#               "confidence": 0.995,
#               "source": "D(1,88,517,117,517,117,532,88,532)"
#             },
#             {
#               "content": "Bank.",
#               "span": {
#                 "offset": 813,
#                 "length": 5
#               },
#               "confidence": 0.995,
#               "source": "D(1,120,517,150,517,150,532,120,532)"
#             },
#             {
#               "content": "These",
#               "span": {
#                 "offset": 819,
#                 "length": 5
#               },
#               "confidence": 0.996,
#               "source": "D(1,153,517,183,517,183,532,153,532)"
#             },
#             {
#               "content": "benefits",
#               "span": {
#                 "offset": 825,
#                 "length": 8
#               },
#               "confidence": 0.994,
#               "source": "D(1,186,517,230,517,230,532,186,532)"
#             },
#             {
#               "content": "were",
#               "span": {
#                 "offset": 834,
#                 "length": 4
#               },
#               "confidence": 0.992,
#               "source": "D(1,233,517,261,517,261,532,233,532)"
#             },
#             {
#               "content": "partially",
#               "span": {
#                 "offset": 839,
#                 "length": 9
#               },
#               "confidence": 0.995,
#               "source": "D(1,264,517,305,517,305,532,264,532)"
#             },
#             {
#               "content": "offset",
#               "span": {
#                 "offset": 849,
#                 "length": 6
#               },
#               "confidence": 0.995,
#               "source": "D(1,308,517,339,518,339,533,308,533)"
#             },
#             {
#               "content": "by",
#               "span": {
#                 "offset": 856,
#                 "length": 2
#               },
#               "confidence": 0.998,
#               "source": "D(1,342,518,354,518,354,533,342,533)"
#             },
#             {
#               "content": "inflationary",
#               "span": {
#                 "offset": 859,
#                 "length": 12
#               },
#               "confidence": 0.992,
#               "source": "D(1,357,518,419,518,419,533,357,533)"
#             },
#             {
#               "content": "pressures",
#               "span": {
#                 "offset": 872,
#                 "length": 9
#               },
#               "confidence": 0.992,
#               "source": "D(1,75,532,126,532,126,546,75,547)"
#             },
#             {
#               "content": "in",
#               "span": {
#                 "offset": 882,
#                 "length": 2
#               },
#               "confidence": 0.995,
#               "source": "D(1,129,532,140,532,140,546,129,546)"
#             },
#             {
#               "content": "the",
#               "span": {
#                 "offset": 885,
#                 "length": 3
#               },
#               "confidence": 0.994,
#               "source": "D(1,144,532,160,532,160,546,144,546)"
#             },
#             {
#               "content": "cost",
#               "span": {
#                 "offset": 889,
#                 "length": 4
#               },
#               "confidence": 0.995,
#               "source": "D(1,163,532,186,532,186,546,163,546)"
#             },
#             {
#               "content": "base,",
#               "span": {
#                 "offset": 894,
#                 "length": 5
#               },
#               "confidence": 0.989,
#               "source": "D(1,189,532,219,532,219,546,189,546)"
#             },
#             {
#               "content": "particularly",
#               "span": {
#                 "offset": 900,
#                 "length": 12
#               },
#               "confidence": 0.987,
#               "source": "D(1,222,532,280,532,280,546,222,546)"
#             },
#             {
#               "content": "in",
#               "span": {
#                 "offset": 913,
#                 "length": 2
#               },
#               "confidence": 0.997,
#               "source": "D(1,283,532,293,532,293,546,283,546)"
#             },
#             {
#               "content": "distribution",
#               "span": {
#                 "offset": 916,
#                 "length": 12
#               },
#               "confidence": 0.992,
#               "source": "D(1,296,532,357,532,357,546,296,546)"
#             },
#             {
#               "content": "costs.",
#               "span": {
#                 "offset": 929,
#                 "length": 6
#               },
#               "confidence": 0.991,
#               "source": "D(1,360,532,392,532,392,546,360,546)"
#             },
#             {
#               "content": "Group",
#               "span": {
#                 "offset": 936,
#                 "length": 5
#               },
#               "confidence": 0.998,
#               "source": "D(1,395,532,430,532,430,546,395,546)"
#             },
#             {
#               "content": "statutory",
#               "span": {
#                 "offset": 942,
#                 "length": 9
#               },
#               "confidence": 0.995,
#               "source": "D(1,75,547,123,547,124,561,75,561)"
#             },
#             {
#               "content": "operating",
#               "span": {
#                 "offset": 952,
#                 "length": 9
#               },
#               "confidence": 0.995,
#               "source": "D(1,126,547,179,547,179,561,126,561)"
#             },
#             {
#               "content": "profit,",
#               "span": {
#                 "offset": 962,
#                 "length": 7
#               },
#               "confidence": 0.993,
#               "source": "D(1,182,547,214,547,214,561,182,561)"
#             },
#             {
#               "content": "which",
#               "span": {
#                 "offset": 970,
#                 "length": 5
#               },
#               "confidence": 0.998,
#               "source": "D(1,217,547,246,547,246,561,217,561)"
#             },
#             {
#               "content": "includes",
#               "span": {
#                 "offset": 976,
#                 "length": 8
#               },
#               "confidence": 0.994,
#               "source": "D(1,249,547,295,547,295,561,249,561)"
#             },
#             {
#               "content": "adjusting",
#               "span": {
#                 "offset": 985,
#                 "length": 9
#               },
#               "confidence": 0.995,
#               "source": "D(1,298,547,343,547,343,561,298,561)"
#             },
#             {
#               "content": "items",
#               "span": {
#                 "offset": 995,
#                 "length": 5
#               },
#               "confidence": 0.995,
#               "source": "D(1,346,547,378,547,378,561,346,561)"
#             },
#             {
#               "content": "related",
#               "span": {
#                 "offset": 1001,
#                 "length": 7
#               },
#               "confidence": 0.996,
#               "source": "D(1,381,547,418,547,418,561,381,561)"
#             },
#             {
#               "content": "to",
#               "span": {
#                 "offset": 1009,
#                 "length": 2
#               },
#               "confidence": 0.992,
#               "source": "D(1,422,547,434,547,434,561,422,561)"
#             },
#             {
#               "content": "the",
#               "span": {
#                 "offset": 1012,
#                 "length": 3
#               },
#               "confidence": 0.995,
#               "source": "D(1,75,561,92,561,92,576,75,576)"
#             },
#             {
#               "content": "costs",
#               "span": {
#                 "offset": 1016,
#                 "length": 5
#               },
#               "confidence": 0.996,
#               "source": "D(1,95,561,125,562,125,576,95,576)"
#             },
#             {
#               "content": "of",
#               "span": {
#                 "offset": 1022,
#                 "length": 2
#               },
#               "confidence": 0.99,
#               "source": "D(1,128,562,137,561,137,576,128,576)"
#             },
#             {
#               "content": "historical",
#               "span": {
#                 "offset": 1025,
#                 "length": 10
#               },
#               "confidence": 0.993,
#               "source": "D(1,140,561,191,562,191,576,140,576)"
#             },
#             {
#               "content": "shareholder",
#               "span": {
#                 "offset": 1036,
#                 "length": 11
#               },
#               "confidence": 0.992,
#               "source": "D(1,194,562,256,561,256,576,194,576)"
#             },
#             {
#               "content": "litigation",
#               "span": {
# ...
#               "rowIndex": 14,
#               "columnIndex": 2,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "5.58p",
#               "source": "D(1,587,916,681,916,681,931,587,931)",
#               "span": {
#                 "offset": 4341,
#                 "length": 5
#               },
#               "elements": [
#                 "/paragraphs/66"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 14,
#               "columnIndex": 3,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "252.0%",
#               "source": "D(1,681,916,757,916,757,931,681,931)",
#               "span": {
#                 "offset": 4356,
#                 "length": 6
#               },
#               "elements": [
#                 "/paragraphs/67"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 14,
#               "columnIndex": 4,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "",
#               "source": "D(1,757,916,836,916,836,931,757,931)",
#               "span": {
#                 "offset": 4372,
#                 "length": 0
#               }
#             },
#             {
#               "kind": "content",
#               "rowIndex": 15,
#               "columnIndex": 0,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "Dividend per share",
#               "source": "D(1,63,931,509,931,509,946,63,946)",
#               "span": {
#                 "offset": 4393,
#                 "length": 18
#               },
#               "elements": [
#                 "/paragraphs/68"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 15,
#               "columnIndex": 1,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "10.90\u0440",
#               "source": "D(1,509,931,587,931,587,946,509,946)",
#               "span": {
#                 "offset": 4421,
#                 "length": 6
#               },
#               "elements": [
#                 "/paragraphs/69"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 15,
#               "columnIndex": 2,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "9.15p",
#               "source": "D(1,587,931,681,931,681,946,587,946)",
#               "span": {
#                 "offset": 4437,
#                 "length": 5
#               },
#               "elements": [
#                 "/paragraphs/70"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 15,
#               "columnIndex": 3,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "19.1%",
#               "source": "D(1,681,931,757,931,757,946,681,946)",
#               "span": {
#                 "offset": 4452,
#                 "length": 5
#               },
#               "elements": [
#                 "/paragraphs/71"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 15,
#               "columnIndex": 4,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "",
#               "source": "D(1,757,931,836,931,836,946,757,946)",
#               "span": {
#                 "offset": 4467,
#                 "length": 0
#               }
#             },
#             {
#               "kind": "content",
#               "rowIndex": 16,
#               "columnIndex": 0,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "Net debt\u21221,11",
#               "source": "D(1,63,946,509,946,509,962,62,961)",
#               "span": {
#                 "offset": 4488,
#                 "length": 13
#               },
#               "elements": [
#                 "/paragraphs/72"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 16,
#               "columnIndex": 1,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "\u00a3(10.5)bn",
#               "source": "D(1,509,946,587,946,587,962,509,962)",
#               "span": {
#                 "offset": 4511,
#                 "length": 9
#               },
#               "elements": [
#                 "/paragraphs/73"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 16,
#               "columnIndex": 2,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "\u00a3(12.0)bn",
#               "source": "D(1,587,946,681,946,681,962,587,962)",
#               "span": {
#                 "offset": 4530,
#                 "length": 9
#               },
#               "elements": [
#                 "/paragraphs/74"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 16,
#               "columnIndex": 3,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "",
#               "source": "D(1,681,946,757,946,757,962,681,962)",
#               "span": {
#                 "offset": 4549,
#                 "length": 0
#               }
#             },
#             {
#               "kind": "content",
#               "rowIndex": 16,
#               "columnIndex": 4,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "",
#               "source": "D(1,757,946,836,946,836,962,757,962)",
#               "span": {
#                 "offset": 4559,
#                 "length": 0
#               }
#             },
#             {
#               "kind": "content",
#               "rowIndex": 17,
#               "columnIndex": 0,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "Retail free cash flow\"",
#               "source": "D(1,62,961,509,962,509,978,62,977)",
#               "span": {
#                 "offset": 4580,
#                 "length": 22
#               },
#               "elements": [
#                 "/paragraphs/75"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 17,
#               "columnIndex": 1,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "\u00a32.3bn",
#               "source": "D(1,509,962,587,962,587,978,509,978)",
#               "span": {
#                 "offset": 4612,
#                 "length": 6
#               },
#               "elements": [
#                 "/paragraphs/76"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 17,
#               "columnIndex": 2,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "\u00a31.3bn",
#               "source": "D(1,587,962,681,962,681,978,587,978)",
#               "span": {
#                 "offset": 4628,
#                 "length": 6
#               },
#               "elements": [
#                 "/paragraphs/77"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 17,
#               "columnIndex": 3,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "",
#               "source": "D(1,681,962,757,962,757,978,681,978)",
#               "span": {
#                 "offset": 4644,
#                 "length": 0
#               }
#             },
#             {
#               "kind": "content",
#               "rowIndex": 17,
#               "columnIndex": 4,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "",
#               "source": "D(1,757,962,836,962,836,978,757,978)",
#               "span": {
#                 "offset": 4654,
#                 "length": 0
#               }
#             },
#             {
#               "kind": "content",
#               "rowIndex": 18,
#               "columnIndex": 0,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "Capex1)",
#               "source": "D(1,62,977,509,978,509,992,62,990)",
#               "span": {
#                 "offset": 4675,
#                 "length": 7
#               },
#               "elements": [
#                 "/paragraphs/78"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 18,
#               "columnIndex": 1,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "\u00a31.1bn",
#               "source": "D(1,509,978,587,978,587,992,509,992)",
#               "span": {
#                 "offset": 4692,
#                 "length": 6
#               },
#               "elements": [
#                 "/paragraphs/79"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 18,
#               "columnIndex": 2,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "\u00a31.0bn",
#               "source": "D(1,587,978,681,978,681,992,587,992)",
#               "span": {
#                 "offset": 4708,
#                 "length": 6
#               },
#               "elements": [
#                 "/paragraphs/80"
#               ]
#             },
#             {
#               "kind": "content",
#               "rowIndex": 18,
#               "columnIndex": 3,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "",
#               "source": "D(1,681,978,757,978,757,992,681,992)",
#               "span": {
#                 "offset": 4724,
#                 "length": 0
#               }
#             },
#             {
#               "kind": "content",
#               "rowIndex": 18,
#               "columnIndex": 4,
#               "rowSpan": 1,
#               "columnSpan": 1,
#               "content": "",
#               "source": "D(1,757,978,836,978,836,992,757,992)",
#               "span": {
#                 "offset": 4734,
#                 "length": 0
#               }
#             }
#           ],
#           "source": "D(1,73,687,832,687,832,995,73,995)",
#           "span": {
#             "offset": 2816,
#             "length": 4815
#           },
#           "footnotes": [
#             {
#               "content": "(a) The Group has defined and outlined the purpose of its alternative performance measures, Including its performance highlights, in the Glossary starting on page 207. During the year, the operating profit and EPS APMs were renamed. Profit has changed from 'Group operating profit before exceptional items and amortisation of acquired intangibles' to 'Adjusted operating profit'. EPS has changed from 'Diluted EPS before exceptional and other Items' to 'Adjusted diluted EPS'. The definitions are unchanged. The Retall free cash flow APM was amended in order to provide a more consistent and predictable view of free cash flow generated by the Group's retal operation. 'Exceptional items and amortisation of acquired intangibles' within operating profit, along with net pension finance costs, fair value remeasurements of financial instruments, and the tax impact of such items (below operating profit), are now called 'Adjusting Items'. The policy for determining adjusting items, and the Items adjusted for, are unchanged from the prior year and hence there is no Impact on previously reported APMs.",
#               "source": "D(1,76,1002,825,1003,825,1068,76,1067)",
#               "span": {
#                 "offset": 4756,
#                 "length": 1102
#               },
#               "elements": [
#                 "/paragraphs/81"
#               ]
#             },
#             {
#               "content": "(b) All measures apart from Net debt are shown on a continuing operations basis unless otherwise stated. Further details on discontinued operations can be found in Note 7, starting on page 140.",
#               "source": "D(1,76,1066,811,1066,811,1077,76,1078)",
#               "span": {
#                 "offset": 5858,
#                 "length": 195
#               },
#               "elements": [
#                 "/paragraphs/82"
#               ]
#             },
#             {
#               "content": "[c) The Group has changed its accounting policy for property buybacks In light of an evolution of accepted practice In relation to the application of IFRS 16 'Leases' to such transactions. Comparatives have been restated for this change in accounting policy (see Note 1 on page 122 for further details).",
#               "source": "D(1,76,1077,828,1077,828,1100,76,1100)",
#               "span": {
#                 "offset": 6053,
#                 "length": 305
#               },
#               "elements": [
#                 "/paragraphs/83"
#               ]
#             },
#             {
#               "content": "(d) Group sales exclude VAT and fuel. Sales change shown on a comparable days basis for Central Europe.",
#               "source": "D(1,75,1098,494,1098,494,1109,75,1109)",
#               "span": {
#                 "offset": 6358,
#                 "length": 105
#               },
#               "elements": [
#                 "/paragraphs/84"
#               ]
#             },
#             {
#               "content": "[e) Adjusted operating profit and Adjusted diluted EPS exclude Adjusting items as noted in footnote (a).",
#               "source": "D(1,76,1109,483,1109,483,1120,76,1120)",
#               "span": {
#                 "offset": 6463,
#                 "length": 106
#               },
#               "elements": [
#                 "/paragraphs/85"
#               ]
#             },
#             {
#               "content": "(f) Net debt and Retall free cash flow exclude Tesco Bank.",
#               "source": "D(1,75,1120,306,1120,306,1131,75,1131)",
#               "span": {
#                 "offset": 6569,
#                 "length": 60
#               },
#               "elements": [
#                 "/paragraphs/86"
#               ]
#             },
#             {
#               "content": "(g) The share base used in Adjusted diluted EPS In the prior year is adjusted to capture the full Impact of the share consolidation which followed the sale of our businesses in Thailand and Malaysia, as if it took place at the start of the 2020/21 financial year. As such, Adjusted diluted EPS (adjusted for share consolidation) Is presented on a basis other than In accordance with IAS 33. Please see page 210 for a reconciliation to Adjusted diluted EPS. Like-for-like Is a measure of growth in Group online sales and sales from stores that have been open for at least a year (at constant exchange rates, excluding VAT and fuel).",
#               "source": "D(1,76,1130,829,1130,829,1173,76,1174)",
#               "span": {
#                 "offset": 6629,
#                 "length": 633
#               },
#               "elements": [
#                 "/paragraphs/87"
#               ]
#             },
#             {
#               "content": "(h) Like-for-like is a measure of growth in Group online sales and sales from stores that have been open for at least a year (at constant exchange rates, excluding VAT and fuel).",
#               "source": "D(1,75,1173,769,1173,769,1184,75,1184)",
#               "span": {
#                 "offset": 7262,
#                 "length": 180
#               },
#               "elements": [
#                 "/paragraphs/88"
#               ]
#             },
#             {
#               "content": "() Capex excludes additions arising from business combinations and buybacks of properties (typically stores), as well as additions relating to decommissioning provisions and similar items.",
#               "source": "D(1,76,1184,817,1183,817,1194,76,1195)",
#               "span": {
#                 "offset": 7442,
#                 "length": 190
#               },
#               "elements": [
#                 "/paragraphs/89"
#               ]
#             }
#           ]
#         }
#       ],
#       "figures": [
#         {
#           "source": "D(1,470,52,830,52,830,305,469,305)",
#           "span": {
#             "offset": 1466,
#             "length": 18
#           },
#           "id": "1.1"
#         }
#       ]
#     }
#   ]
# }

# %%
analyzer_content
# Out:
# [{'id': 'hackathon_financial',
#   'content': [{'markdown': '<!-- PageHeader="Strategic report" -->\n<!-- PageHeader="Financial review" -->\n\n\n# Group review of performance.\n\nGroup sales increased by +3.0% at constant rates, with growth\nacross all regions on top of exceptionally strong sales last year.\nRevenue increased by +6.4% at constant rates including fuel sales\ngrowth of +48.1% as customers travelled more following the easing\nof government restrictions. While two-year like-for-like" fuel sales\ngrowth was negative at (6.4)%, this primarily reflects lower demand\nin the first half, with fuel sales ahead of pre-pandemic levels by the\nend of the year.\n\nGroup adjusted operating profit* grew by +58.9% at constant rates,\nreflecting the strong sales performance across the retail businesses,\na reduction in COVID-19 related costs and a return to profitability\nin Tesco Bank. These benefits were partially offset by inflationary\npressures in the cost base, particularly in distribution costs. Group\nstatutory operating profit, which includes adjusting items related to\nthe costs of historical shareholder litigation claims, grew by +65.5%.\n\nFinance income and finance costs reduced year-on-year primarily\ndue to fair value remeasurement gains related to the mark-to-\nmarket movement on inflation-linked swaps, which were a £123m\nbenefit this year compared to a £(214)m charge in the prior year.\nThe reduction in our share of profit from joint ventures and\nassociates was principally due to profit from Tesco Underwriting\n\n\n<figure>\n</figure>\n\n\nbeing recognised within Tesco Bank operating profit following its\nfull acquisition in May. The increase in tax this year primarily reflects\nhigher levels of both retail and Tesco Bank operating profit, in addition\nto the revaluation of deferred tax relating to the announced change\nin the UK corporation tax rate from 19% to 25%, effective 1 April 2023.\n\nOur adjusted diluted EPSlø rose by +88.8%, reflecting the increase\nin retail and Tesco Bank operating profit and a reduction in net\nfinance costs. We have proposed a final dividend of 7.70 pence\nper ordinary share, taking the full-year dividend to 10.90 pence\nper ordinary share, an increase of 19.1% year-on-year.\n\nNet debtlt1.00 reduced by £1.4bn year-on-year, primarily driven by\nstrong free cash flow generation. Retail free cash flow" increased\nby £0.9bn year-on-year due to higher retail operating profits, the\nelimination of UK pension contributions (following the £2.5bn one-off\ncontribution last year from the Asia disposal proceeds) and a working\ncapital benefit from higher sales. These benefits were partly offset\nby an increase in capital expenditure. The Net debt/EBITDA ratio was\n2.5 times at the year end, compared to 3.3 times last year.\n\nFurther commentary on all of these metrics can be found below and\na full income statement can be found on page 116.\n\n\n<table>\n<tr>\n<th rowspan="2">52 weeks ended 26 February 202221</th>\n<th rowspan="2">FY 2021/22</th>\n<th rowspan="2">FY0 2020/21</th>\n<th colspan="2">Total change YoY</th>\n</tr>\n<tr>\n<th>Actual rate</th>\n<th>Constant rate</th>\n</tr>\n<tr>\n<td>Group sales (exc. VAT, exc. fuel)(d)</td>\n<td>£54,768m</td>\n<td>£53,445m</td>\n<td>2.5%</td>\n<td>3.0%</td>\n</tr>\n<tr>\n<td>Fuel</td>\n<td>£6,576m</td>\n<td>£4,442m</td>\n<td>48.1%</td>\n<td>48.1%</td>\n</tr>\n<tr>\n<td>Revenue (exc. VAT, inc. fuel)</td>\n<td>£61,344m</td>\n<td>£57,887m</td>\n<td>6.0%</td>\n<td>6.4%</td>\n</tr>\n<tr>\n<td>Adjusted operating profit **</td>\n<td>£2,825m</td>\n<td>£1,788m</td>\n<td>58.0%</td>\n<td>58.9%</td>\n</tr>\n<tr>\n<td>Adjusting items</td>\n<td>£(265)m</td>\n<td>£(241)m</td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td>Group statutory operating profit</td>\n<td>£2,560m</td>\n<td>£1,547m</td>\n<td>65.5%</td>\n<td></td>\n</tr>\n<tr>\n<td>Net finance costs</td>\n<td>£(542)m</td>\n<td>£(937)m</td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td>Joint ventures and associates</td>\n<td>£15m</td>\n<td>£26m</td ...
#     'fields': {'Total_Assets': {'type': 'string'},
#      'Current_Assets': {'type': 'string'},
#      'Inventory': {'type': 'string'},
#      'Cash': {'type': 'string'},
#      'Marketable_Securities': {'type': 'string'},
#      'Accounts_Receivable': {'type': 'string'},
#      'Accounts_Payable': {'type': 'string'},
#      'Total_Liabilities': {'type': 'string'},
#      'Current_Liabilities': {'type': 'string'},
#      'Total_Debt': {'type': 'string'},
#      'Shareholders_Equity': {'type': 'string'},
#      'Revenue_a_k_a_Sales': {'type': 'string', 'valueString': '£61,344m'},
#      'Cost_of_Goods_Sold_COGS': {'type': 'string'},
#      'Operating_Income_EBIT': {'type': 'string', 'valueString': '£2,825m'},
#      'EBITDA': {'type': 'string'},
#      'Net_Income': {'type': 'string', 'valueString': '£1,523m'},
#      'Operating_Expenses_and_sub_items_SG_A_Advertising_R_D': {'type': 'string'},
#      'Interest_Expense': {'type': 'string'},
#      'Interest_Income': {'type': 'string'},
#      'Lease_Expense': {'type': 'string'},
#      'Depreciation': {'type': 'string'},
#      'Amortization': {'type': 'string'},
#      'Capital_Expenditures_Capex': {'type': 'string', 'valueString': '£1.1bn'},
#      'Operating_Cash_Flow': {'type': 'string'},
#      'Net_Patient_Revenue': {'type': 'string'},
#      'Net_Operating_Income_NOI': {'type': 'string'},
#      'Rental_Revenue': {'type': 'string'},
#      'Order_Backlog': {'type': 'string'},
#      'Work_in_Progress': {'type': 'string'},
#      'Total_Contract_Value': {'type': 'string'},
#      'Retention_Receivables': {'type': 'string'},
#      'Contract_Revenue': {'type': 'string'},
#      'Reserves_Added': {'type': 'string'},
#      'Reserves_Extracted_Produced': {'type': 'string'},
#      'Total_Production': {'type': 'string'},
#      'Production_Transport_Costs': {'type': 'string'},
#      'Barrels_Produced': {'type': 'string'},
#      'Loan_Amount': {'type': 'string'},
#      'Collateral_Value_Property_Value': {'type': 'string'},
#      'Debt_Service_Principal_Interest_Payments': {'type': 'string'},
#      'Annual_Admissions': {'type': 'string'},
#      'Average_Number_of_Beds': {'type': 'string'},
#      'Operating_Expenses_ex_Depreciation': {'type': 'string'},
#      'Earning_Assets': {'type': 'string'},
#      'Average_Earning_Assets': {'type': 'string'},
#      'Loan_Loss_Provisions': {'type': 'string'},
#      'Total_Loans': {'type': 'string'},
#      'Leased_Space': {'type': 'string'},
#      'Total_Available_Space': {'type': 'string'},
#      'Average_Subscribers': {'type': 'string'},
#      'Total_Service_Revenue': {'type': 'string'},
#      'Subscribers_at_Start_End_of_Period': {'type': 'string'},
#      'Customers_at_Start_End_of_Period': {'type': 'string'},
#      'Annual_Recurring_Revenue_ARR': {'type': 'string'},
#      'Number_of_Transactions': {'type': 'string'},
#      'Foot_Traffic': {'type': 'string'},
#      'Sales_for_Stores_Open_gt_1_Year': {'type': 'string'},
#      'Physical_Inventory_Count': {'type': 'string'},
#      'Recorded_Inventory': {'type': 'string'},
#      'Number_of_Drug_Trials_Total_and_Successful': {'type': 'string'},
#      'Sales_from_Patent_Protected_Drugs': {'type': 'string'},
#      'Market_Value_of_Equity_MVE': {'type': 'string'}},
#     'kind': 'document',
#     'startPageNumber': 1,
#     'endPageNumber': 1,
#     'unit': 'pixel',
#     'pages': [{'pageNumber': 1,
#       'angle': 0.03283107,
#       'width': 906,
#       'height': 1258,
#       'spans': [{'offset': 0, 'length': 7735}],
#       'words': [{'content': 'Strategic',
#         'span': {'offset': 17, 'length': 9},
#         'confidence': 0.995,
#         'source': 'D(1,686,0,737,0,737,11,686,11)'},
#        {'content': 'report',
#         'span': {'offset': 27, 'length': 6},
#         'confidence': 0.996,
#         'source': 'D(1,740,0,778,0,778,11,740,11)'},
#        {'content': 'Financial',
#         'span': {'offset': 56, 'length': 9},
#         'confidence': 0.994,
#         'source': 'D(1,75,51,149,51,149,70,75,70)'},
#        {'content': 'review',
#         'span': {'offset': 66, 'length': 6},
#         'confidence': 0.998,
#         'source': 'D(1,155,51,212,51,212,70,155,70)'},
#        {'content': 'Group',
#         'span': {'offset': 82, 'length': 5},
#         'confidence': 0.997,
#         'source': 'D(1,73,125,247,128,247,186,72,182)'},
#        {'content': 'review',
#         'span': {'offset': 88, 'length': 6},
#         'confidence': 0.998,
#         'source': 'D(1,73,192,254,191,254,244,73,245)'},
#        {'content': 'of',
#         'span': {'offset': 95, 'length': 2},
#         'confidence': 0.995,
#         'source': 'D(1,272,191,328,191,328,244,272,244)'},
#        {'content': 'performance.',
#         'span': {'offset': 98, 'length': 12},
#         'confidence': 0.992,
#         'source': 'D(1,73,261,444,260,444,311,74,319)'},
#        {'content': 'Group',
#         'span': {'offset': 112, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,75,339,109,339,109,354,75,354)'},
#        {'content': 'sales',
#         'span': {'offset': 118, 'length': 5},
#         'confidence': 0.841,
#         'source': 'D(1,112,339,140,339,140,354,112,354)'},
#        {'content': 'increased',
#         'span': {'offset': 124, 'length': 9},
#         'confidence': 0.977,
#         'source': 'D(1,147,339,200,339,200,354,147,354)'},
#        {'content': 'by',
#         'span': {'offset': 134, 'length': 2},
#         'confidence': 0.996,
#         'source': 'D(1,203,339,216,339,216,354,203,354)'},
#        {'content': '+3.0%',
#         'span': {'offset': 137, 'length': 5},
#         'confidence': 0.992,
#         'source': 'D(1,219,339,253,339,253,354,219,354)'},
#        {'content': 'at',
#         'span': {'offset': 143, 'length': 2},
#         'confidence': 0.994,
#         'source': 'D(1,256,339,266,339,266,355,256,354)'},
#        {'content': 'constant',
#         'span': {'offset': 146, 'length': 8},
#         'confidence': 0.995,
#         'source': 'D(1,269,339,315,339,315,355,269,355)'},
#        {'content': 'rates,',
#         'span': {'offset': 155, 'length': 6},
#         'confidence': 0.992,
#         'source': 'D(1,318,339,350,339,350,354,318,355)'},
#        {'content': 'with',
#         'span': {'offset': 162, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,353,339,375,339,375,355,353,354)'},
#        {'content': 'growth',
#         'span': {'offset': 167, 'length': 6},
#         'confidence': 0.995,
#         'source': 'D(1,378,339,418,339,418,355,378,355)'},
#        {'content': 'across',
#         'span': {'offset': 174, 'length': 6},
#         'confidence': 0.992,
#         'source': 'D(1,75,355,110,355,110,369,75,369)'},
#        {'content': 'all',
#         'span': {'offset': 181, 'length': 3},
#         'confidence': 0.992,
#         'source': 'D(1,112,355,125,355,125,369,112,369)'},
#        {'content': 'regions',
#         'span': {'offset': 185, 'length': 7},
#         'confidence': 0.993,
#         'source': 'D(1,128,355,166,355,166,369,129,369)'},
#        {'content': 'on',
#         'span': {'offset': 193, 'length': 2},
#         'confidence': 0.996,
#         'source': 'D(1,169,355,183,355,183,370,169,370)'},
#        {'content': 'top',
#         'span': {'offset': 196, 'length': 3},
#         'confidence': 0.996,
#         'source': 'D(1,186,355,204,355,204,370,186,370)'},
#        {'content': 'of',
#         'span': {'offset': 200, 'length': 2},
#         'confidence': 0.995,
#         'source': 'D(1,206,355,218,355,218,370,206,370)'},
#        {'content': 'exceptionally',
#         'span': {'offset': 203, 'length': 13},
#         'confidence': 0.989,
#         'source': 'D(1,221,355,290,355,290,370,221,370)'},
#        {'content': 'strong',
#         'span': {'offset': 217, 'length': 6},
#         'confidence': 0.995,
#         'source': 'D(1,293,355,327,355,327,370,293,370)'},
#        {'content': 'sales',
#         'span': {'offset': 224, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,330,355,357,355,357,370,330,370)'},
#        {'content': 'last',
#         'span': {'offset': 230, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,360,355,377,355,377,370,360,370)'},
#        {'content': 'year.',
#         'span': {'offset': 235, 'length': 5},
#         'confidence': 0.992,
#         'source': 'D(1,380,355,408,355,408,369,380,370)'},
#        {'content': 'Revenue',
#         'span': {'offset': 241, 'length': 7},
#         'confidence': 0.992,
#         'source': 'D(1,75,369,119,369,119,384,75,384)'},
#        {'content': 'increased',
#         'span': {'offset': 249, 'length': 9},
#         'confidence': 0.992,
#         'source': 'D(1,122,369,175,369,175,384,122,384)'},
#        {'content': 'by',
#         'span': {'offset': 259, 'length': 2},
#         'confidence': 0.981,
#         'source': 'D(1,178,369,191,369,191,384,178,384)'},
#        {'content': '+6.4%',
#         'span': {'offset': 262, 'length': 5},
#         'confidence': 0.992,
#         'source': 'D(1,193,369,228,369,228,384,194,384)'},
#        {'content': 'at',
#         'span': {'offset': 268, 'length': 2},
#         'confidence': 0.993,
#         'source': 'D(1,231,369,241,369,241,384,231,384)'},
#        {'content': 'constant',
#         'span': {'offset': 271, 'length': 8},
#         'confidence': 0.993,
#         'source': 'D(1,244,369,290,369,290,384,244,384)'},
#        {'content': 'rates',
#         'span': {'offset': 280, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,293,369,320,369,320,384,293,384)'},
#        {'content': 'including',
#         'span': {'offset': 286, 'length': 9},
#         'confidence': 0.99,
#         'source': 'D(1,323,369,372,369,372,384,322,384)'},
#        {'content': 'fuel',
#         'span': {'offset': 296, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,375,369,394,370,394,384,375,384)'},
#        {'content': 'sales',
#         'span': {'offset': 301, 'length': 5},
#         'confidence': 0.996,
#         'source': 'D(1,397,370,425,370,425,384,397,384)'},
#        {'content': 'growth',
#         'span': {'offset': 307, 'length': 6},
#         'confidence': 0.998,
#         'source': 'D(1,75,384,112,384,112,398,75,399)'},
#        {'content': 'of',
#         'span': {'offset': 314, 'length': 2},
#         'confidence': 0.997,
#         'source': 'D(1,115,384,125,384,125,398,115,398)'},
#        {'content': '+48.1%',
#         'span': {'offset': 317, 'length': 6},
#         'confidence': 0.998,
#         'source': 'D(1,128,384,166,384,166,398,128,398)'},
#        {'content': 'as',
#         'span': {'offset': 324, 'length': 2},
#         'confidence': 0.998,
#         'source': 'D(1,169,384,180,384,180,398,169,398)'},
#        {'content': 'customers',
#         'span': {'offset': 327, 'length': 9},
#         'confidence': 0.995,
#         'source': 'D(1,183,384,238,384,238,398,183,398)'},
#        {'content': 'travelled',
#         'span': {'offset': 337, 'length': 9},
#         'confidence': 0.995,
#         'source': 'D(1,241,384,286,384,286,398,241,398)'},
#        {'content': 'more',
#         'span': {'offset': 347, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,289,384,317,384,317,399,289,398)'},
#        {'content': 'following',
#         'span': {'offset': 352, 'length': 9},
#         'confidence': 0.995,
#         'source': 'D(1,320,384,367,384,367,399,320,399)'},
#        {'content': 'the',
#         'span': {'offset': 362, 'length': 3},
#         'confidence': 0.999,
#         'source': 'D(1,370,384,388,384,388,399,370,399)'},
#        {'content': 'easing',
#         'span': {'offset': 366, 'length': 6},
#         'confidence': 0.997,
#         'source': 'D(1,391,384,426,384,426,399,391,399)'},
#        {'content': 'of',
#         'span': {'offset': 373, 'length': 2},
#         'confidence': 0.992,
#         'source': 'D(1,75,399,86,399,86,413,75,414)'},
#        {'content': 'government',
#         'span': {'offset': 376, 'length': 10},
#         'confidence': 0.992,
#         'source': 'D(1,88,399,152,399,152,413,88,413)'},
#        {'content': 'restrictions.',
#         'span': {'offset': 387, 'length': 13},
#         'confidence': 0.992,
#         'source': 'D(1,155,399,221,399,221,413,155,413)'},
#        {'content': 'While',
#         'span': {'offset': 401, 'length': 5},
#         'confidence': 0.997,
#         'source': 'D(1,224,399,253,399,253,413,224,413)'},
#        {'content': 'two-year',
#         'span': {'offset': 407, 'length': 8},
#         'confidence': 0.992,
#         'source': 'D(1,256,399,302,398,302,413,256,413)'},
#        {'content': 'like-for-like"',
#         'span': {'offset': 416, 'length': 14},
#         'confidence': 0.576,
#         'source': 'D(1,305,398,377,398,377,413,305,413)'},
#        {'content': 'fuel',
#         'span': {'offset': 431, 'length': 4},
#         'confidence': 0.994,
#         'source': 'D(1,380,398,399,398,399,413,380,413)'},
#        {'content': 'sales',
#         'span': {'offset': 436, 'length': 5},
#         'confidence': 0.997,
#         'source': 'D(1,402,398,430,399,430,413,402,413)'},
#        {'content': 'growth',
#         'span': {'offset': 442, 'length': 6},
#         'confidence': 0.993,
#         'source': 'D(1,75,414,111,414,111,429,75,429)'},
#        {'content': 'was',
#         'span': {'offset': 449, 'length': 3},
#         'confidence': 0.997,
#         'source': 'D(1,114,414,134,414,134,429,114,429)'},
#        {'content': 'negative',
#         'span': {'offset': 453, 'length': 8},
#         'confidence': 0.996,
#         'source': 'D(1,137,414,182,414,182,429,137,429)'},
#        {'content': 'at',
#         'span': {'offset': 462, 'length': 2},
#         'confidence': 0.992,
#         'source': 'D(1,185,414,196,414,196,429,185,429)'},
#        {'content': '(6.4)%,',
#         'span': {'offset': 465, 'length': 7},
#         'confidence': 0.977,
#         'source': 'D(1,199,414,236,414,236,429,199,429)'},
#        {'content': 'this',
#         'span': {'offset': 473, 'length': 4},
#         'confidence': 0.993,
#         'source': 'D(1,239,414,259,413,259,429,239,429)'},
#        {'content': 'primarily',
#         'span': {'offset': 478, 'length': 9},
#         'confidence': 0.992,
#         'source': 'D(1,262,413,306,413,306,428,262,429)'},
#        {'content': 'reflects',
#         'span': {'offset': 488, 'length': 8},
#         'confidence': 0.992,
#         'source': 'D(1,309,413,349,413,349,428,309,428)'},
#        {'content': 'lower',
#         'span': {'offset': 497, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,352,413,383,414,383,428,352,428)'},
#        {'content': 'demand',
#         'span': {'offset': 503, 'length': 6},
#         'confidence': 0.993,
#         'source': 'D(1,386,414,431,414,431,428,386,428)'},
#        {'content': 'in',
#         'span': {'offset': 510, 'length': 2},
#         'confidence': 0.995,
#         'source': 'D(1,75,428,83,428,83,443,75,443)'},
#        {'content': 'the',
#         'span': {'offset': 513, 'length': 3},
#         'confidence': 0.994,
#         'source': 'D(1,86,428,104,428,104,443,86,443)'},
#        {'content': 'first',
#         'span': {'offset': 517, 'length': 5},
#         'confidence': 0.993,
#         'source': 'D(1,107,428,128,428,128,443,107,443)'},
#        {'content': 'half,',
#         'span': {'offset': 523, 'length': 5},
#         'confidence': 0.977,
#         'source': 'D(1,131,428,156,428,156,443,131,443)'},
#        {'content': 'with',
#         'span': {'offset': 529, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,159,428,181,428,181,443,159,443)'},
#        {'content': 'fuel',
#         'span': {'offset': 534, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,184,428,204,428,204,444,184,443)'},
#        {'content': 'sales',
#         'span': {'offset': 539, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,207,428,234,428,234,444,207,444)'},
#        {'content': 'ahead',
#         'span': {'offset': 545, 'length': 5},
#         'confidence': 0.994,
#         'source': 'D(1,237,428,269,428,269,444,237,444)'},
#        {'content': 'of',
#         'span': {'offset': 551, 'length': 2},
#         'confidence': 0.992,
#         'source': 'D(1,272,428,281,428,281,444,272,444)'},
#        {'content': 'pre-pandemic',
#         'span': {'offset': 554, 'length': 12},
#         'confidence': 0.989,
#         'source': 'D(1,284,428,362,428,362,444,284,444)'},
#        {'content': 'levels',
#         'span': {'offset': 567, 'length': 6},
#         'confidence': 0.993,
#         'source': 'D(1,366,428,395,428,395,444,366,444)'},
#        {'content': 'by',
#         'span': {'offset': 574, 'length': 2},
#         'confidence': 0.999,
#         'source': 'D(1,398,428,409,428,408,444,398,444)'},
#        {'content': 'the',
#         'span': {'offset': 577, 'length': 3},
#         'confidence': 0.996,
#         'source': 'D(1,412,428,432,428,432,443,411,444)'},
#        {'content': 'end',
#         'span': {'offset': 581, 'length': 3},
#         'confidence': 0.997,
#         'source': 'D(1,75,444,96,444,96,458,75,458)'},
#        {'content': 'of',
#         'span': {'offset': 585, 'length': 2},
#         'confidence': 0.997,
#         'source': 'D(1,99,444,110,444,110,458,99,458)'},
#        {'content': 'the',
#         'span': {'offset': 588, 'length': 3},
#         'confidence': 0.999,
#         'source': 'D(1,113,444,131,444,131,458,113,458)'},
#        {'content': 'year.',
#         'span': {'offset': 592, 'length': 5},
#         'confidence': 0.992,
#         'source': 'D(1,133,444,160,444,160,458,133,458)'},
#        {'content': 'Group',
#         'span': {'offset': 599, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,75,472,108,472,108,487,75,487)'},
#        {'content': 'adjusted',
#         'span': {'offset': 605, 'length': 8},
#         'confidence': 0.992,
#         'source': 'D(1,111,472,158,472,158,488,111,488)'},
#        {'content': 'operating',
#         'span': {'offset': 614, 'length': 9},
#         'confidence': 0.992,
#         'source': 'D(1,161,472,211,472,211,488,161,488)'},
#        {'content': 'profit*',
#         'span': {'offset': 624, 'length': 7},
#         'confidence': 0.639,
#         'source': 'D(1,214,472,250,472,250,488,214,488)'},
#        {'content': 'grew',
#         'span': {'offset': 632, 'length': 4},
#         'confidence': 0.99,
#         'source': 'D(1,253,472,278,472,278,488,253,488)'},
#        {'content': 'by',
#         'span': {'offset': 637, 'length': 2},
#         'confidence': 0.996,
#         'source': 'D(1,281,472,295,472,295,488,281,488)'},
#        {'content': '+58.9%',
#         'span': {'offset': 640, 'length': 6},
#         'confidence': 0.992,
#         'source': 'D(1,298,472,337,472,337,488,298,488)'},
#        {'content': 'at',
#         'span': {'offset': 647, 'length': 2},
#         'confidence': 0.998,
#         'source': 'D(1,340,472,350,472,350,488,340,488)'},
#        {'content': 'constant',
#         'span': {'offset': 650, 'length': 8},
#         'confidence': 0.993,
#         'source': 'D(1,353,472,399,472,399,487,353,488)'},
#        {'content': 'rates,',
#         'span': {'offset': 659, 'length': 6},
#         'confidence': 0.973,
#         'source': 'D(1,402,472,435,472,435,487,402,487)'},
#        {'content': 'reflecting',
#         'span': {'offset': 666, 'length': 10},
#         'confidence': 0.992,
#         'source': 'D(1,75,488,125,488,125,502,75,502)'},
#        {'content': 'the',
#         'span': {'offset': 677, 'length': 3},
#         'confidence': 0.997,
#         'source': 'D(1,128,488,147,488,147,502,128,502)'},
#        {'content': 'strong',
#         'span': {'offset': 681, 'length': 6},
#         'confidence': 0.996,
#         'source': 'D(1,150,488,183,488,183,502,150,502)'},
#        {'content': 'sales',
#         'span': {'offset': 688, 'length': 5},
#         'confidence': 0.996,
#         'source': 'D(1,186,488,211,488,211,502,186,502)'},
#        {'content': 'performance',
#         'span': {'offset': 694, 'length': 11},
#         'confidence': 0.995,
#         'source': 'D(1,214,488,286,488,286,502,214,502)'},
#        {'content': 'across',
#         'span': {'offset': 706, 'length': 6},
#         'confidence': 0.994,
#         'source': 'D(1,289,488,324,488,324,502,289,502)'},
#        {'content': 'the',
#         'span': {'offset': 713, 'length': 3},
#         'confidence': 0.998,
#         'source': 'D(1,327,488,343,488,343,502,327,502)'},
#        {'content': 'retail',
#         'span': {'offset': 717, 'length': 6},
#         'confidence': 0.992,
#         'source': 'D(1,346,488,373,488,373,502,346,502)'},
#        {'content': 'businesses,',
#         'span': {'offset': 724, 'length': 11},
#         'confidence': 0.936,
#         'source': 'D(1,376,488,440,488,439,502,376,502)'},
#        {'content': 'a',
#         'span': {'offset': 736, 'length': 1},
#         'confidence': 0.977,
#         'source': 'D(1,75,502,80,502,80,517,75,517)'},
#        {'content': 'reduction',
#         'span': {'offset': 738, 'length': 9},
#         'confidence': 0.989,
#         'source': 'D(1,83,502,134,502,134,517,83,517)'},
#        {'content': 'in',
#         'span': {'offset': 748, 'length': 2},
#         'confidence': 0.994,
#         'source': 'D(1,137,502,149,502,149,517,137,517)'},
#        {'content': 'COVID-19',
#         'span': {'offset': 751, 'length': 8},
#         'confidence': 0.992,
#         'source': 'D(1,152,502,199,502,199,517,152,517)'},
#        {'content': 'related',
#         'span': {'offset': 760, 'length': 7},
#         'confidence': 0.994,
#         'source': 'D(1,202,502,242,502,242,517,202,517)'},
#        {'content': 'costs',
#         'span': {'offset': 768, 'length': 5},
#         'confidence': 0.994,
#         'source': 'D(1,245,502,274,502,274,517,245,517)'},
#        {'content': 'and',
#         'span': {'offset': 774, 'length': 3},
#         'confidence': 0.993,
#         'source': 'D(1,277,502,296,502,296,517,277,517)'},
#        {'content': 'a',
#         'span': {'offset': 778, 'length': 1},
#         'confidence': 0.994,
#         'source': 'D(1,300,502,304,502,304,517,300,517)'},
#        {'content': 'return',
#         'span': {'offset': 780, 'length': 6},
#         'confidence': 0.992,
#         'source': 'D(1,307,502,343,503,343,517,307,517)'},
#        {'content': 'to',
#         'span': {'offset': 787, 'length': 2},
#         'confidence': 0.997,
#         'source': 'D(1,346,503,357,503,357,517,345,517)'},
#        {'content': 'profitability',
#         'span': {'offset': 790, 'length': 13},
#         'confidence': 0.991,
#         'source': 'D(1,360,503,422,503,422,518,360,517)'},
#        {'content': 'in',
#         'span': {'offset': 804, 'length': 2},
#         'confidence': 0.993,
#         'source': 'D(1,75,517,85,517,85,532,75,532)'},
#        {'content': 'Tesco',
#         'span': {'offset': 807, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,88,517,117,517,117,532,88,532)'},
#        {'content': 'Bank.',
#         'span': {'offset': 813, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,120,517,150,517,150,532,120,532)'},
#        {'content': 'These',
#         'span': {'offset': 819, 'length': 5},
#         'confidence': 0.996,
#         'source': 'D(1,153,517,183,517,183,532,153,532)'},
#        {'content': 'benefits',
#         'span': {'offset': 825, 'length': 8},
#         'confidence': 0.994,
#         'source': 'D(1,186,517,230,517,230,532,186,532)'},
#        {'content': 'were',
#         'span': {'offset': 834, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,233,517,261,517,261,532,233,532)'},
#        {'content': 'partially',
#         'span': {'offset': 839, 'length': 9},
#         'confidence': 0.995,
#         'source': 'D(1,264,517,305,517,305,532,264,532)'},
#        {'content': 'offset',
#         'span': {'offset': 849, 'length': 6},
#         'confidence': 0.995,
#         'source': 'D(1,308,517,339,518,339,533,308,533)'},
#        {'content': 'by',
#         'span': {'offset': 856, 'length': 2},
#         'confidence': 0.998,
#         'source': 'D(1,342,518,354,518,354,533,342,533)'},
#        {'content': 'inflationary',
#         'span': {'offset': 859, 'length': 12},
#         'confidence': 0.992,
#         'source': 'D(1,357,518,419,518,419,533,357,533)'},
#        {'content': 'pressures',
#         'span': {'offset': 872, 'length': 9},
#         'confidence': 0.992,
#         'source': 'D(1,75,532,126,532,126,546,75,547)'},
#        {'content': 'in',
#         'span': {'offset': 882, 'length': 2},
#         'confidence': 0.995,
#         'source': 'D(1,129,532,140,532,140,546,129,546)'},
#        {'content': 'the',
#         'span': {'offset': 885, 'length': 3},
#         'confidence': 0.994,
#         'source': 'D(1,144,532,160,532,160,546,144,546)'},
#        {'content': 'cost',
#         'span': {'offset': 889, 'length': 4},
#         'confidence': 0.995,
#         'source': 'D(1,163,532,186,532,186,546,163,546)'},
#        {'content': 'base,',
#         'span': {'offset': 894, 'length': 5},
#         'confidence': 0.989,
#         'source': 'D(1,189,532,219,532,219,546,189,546)'},
#        {'content': 'particularly',
#         'span': {'offset': 900, 'length': 12},
#         'confidence': 0.987,
#         'source': 'D(1,222,532,280,532,280,546,222,546)'},
#        {'content': 'in',
#         'span': {'offset': 913, 'length': 2},
#         'confidence': 0.997,
#         'source': 'D(1,283,532,293,532,293,546,283,546)'},
#        {'content': 'distribution',
#         'span': {'offset': 916, 'length': 12},
#         'confidence': 0.992,
#         'source': 'D(1,296,532,357,532,357,546,296,546)'},
#        {'content': 'costs.',
#         'span': {'offset': 929, 'length': 6},
#         'confidence': 0.991,
#         'source': 'D(1,360,532,392,532,392,546,360,546)'},
#        {'content': 'Group',
#         'span': {'offset': 936, 'length': 5},
#         'confidence': 0.998,
#         'source': 'D(1,395,532,430,532,430,546,395,546)'},
#        {'content': 'statutory',
#         'span': {'offset': 942, 'length': 9},
#         'confidence': 0.995,
#         'source': 'D(1,75,547,123,547,124,561,75,561)'},
#        {'content': 'operating',
#         'span': {'offset': 952, 'length': 9},
#         'confidence': 0.995,
#         'source': 'D(1,126,547,179,547,179,561,126,561)'},
#        {'content': 'profit,',
#         'span': {'offset': 962, 'length': 7},
#         'confidence': 0.993,
#         'source': 'D(1,182,547,214,547,214,561,182,561)'},
#        {'content': 'which',
#         'span': {'offset': 970, 'length': 5},
#         'confidence': 0.998,
#         'source': 'D(1,217,547,246,547,246,561,217,561)'},
#        {'content': 'includes',
#         'span': {'offset': 976, 'length': 8},
#         'confidence': 0.994,
#         'source': 'D(1,249,547,295,547,295,561,249,561)'},
#        {'content': 'adjusting',
#         'span': {'offset': 985, 'length': 9},
#         'confidence': 0.995,
#         'source': 'D(1,298,547,343,547,343,561,298,561)'},
#        {'content': 'items',
#         'span': {'offset': 995, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,346,547,378,547,378,561,346,561)'},
#        {'content': 'related',
#         'span': {'offset': 1001, 'length': 7},
#         'confidence': 0.996,
#         'source': 'D(1,381,547,418,547,418,561,381,561)'},
#        {'content': 'to',
#         'span': {'offset': 1009, 'length': 2},
#         'confidence': 0.992,
#         'source': 'D(1,422,547,434,547,434,561,422,561)'},
#        {'content': 'the',
#         'span': {'offset': 1012, 'length': 3},
#         'confidence': 0.995,
#         'source': 'D(1,75,561,92,561,92,576,75,576)'},
#        {'content': 'costs',
#         'span': {'offset': 1016, 'length': 5},
#         'confidence': 0.996,
#         'source': 'D(1,95,561,125,562,125,576,95,576)'},
#        {'content': 'of',
#         'span': {'offset': 1022, 'length': 2},
#         'confidence': 0.99,
#         'source': 'D(1,128,562,137,561,137,576,128,576)'},
#        {'content': 'historical',
#         'span': {'offset': 1025, 'length': 10},
#         'confidence': 0.993,
#         'source': 'D(1,140,561,191,562,191,576,140,576)'},
#        {'content': 'shareholder',
#         'span': {'offset': 1036, 'length': 11},
#         'confidence': 0.992,
#         'source': 'D(1,194,562,256,561,256,576,194,576)'},
#        {'content': 'litigation',
#         'span': {'offset': 1048, 'length': 10},
#         'confidence': 0.993,
#         'source': 'D(1,259,561,306,562,306,577,259,576)'},
#        {'content': 'claims,',
#         'span': {'offset': 1059, 'length': 7},
#         'confidence': 0.993,
#         'source': 'D(1,309,562,345,562,345,577,309,577)'},
#        {'content': 'grew',
#         'span': {'offset': 1067, 'length': 4},
#         'confidence': 0.99,
#         'source': 'D(1,348,562,374,562,374,576,348,577)'},
#        {'content': 'by',
#         'span': {'offset': 1072, 'length': 2},
#         'confidence': 0.997,
#         'source': 'D(1,377,562,390,562,390,576,377,576)'},
#        {'content': '+65.5%.',
#         'span': {'offset': 1075, 'length': 7},
#         'confidence': 0.992,
#         'source': 'D(1,393,562,436,562,436,576,393,576)'},
#        {'content': 'Finance',
#         'span': {'offset': 1084, 'length': 7},
#         'confidence': 0.994,
#         'source': 'D(1,75,591,114,591,114,606,75,606)'},
#        {'content': 'income',
#         'span': {'offset': 1092, 'length': 6},
#         'confidence': 0.992,
#         'source': 'D(1,117,591,159,591,159,606,117,606)'},
#        {'content': 'and',
#         'span': {'offset': 1099, 'length': 3},
#         'confidence': 0.995,
#         'source': 'D(1,162,591,180,591,180,606,162,606)'},
#        {'content': 'finance',
#         'span': {'offset': 1103, 'length': 7},
#         'confidence': 0.992,
#         'source': 'D(1,183,591,224,591,224,606,183,606)'},
#        {'content': 'costs',
#         'span': {'offset': 1111, 'length': 5},
#         'confidence': 0.993,
#         'source': 'D(1,227,591,254,591,254,607,227,607)'},
#        {'content': 'reduced',
#         'span': {'offset': 1117, 'length': 7},
#         'confidence': 0.992,
#         'source': 'D(1,257,591,303,592,303,607,257,607)'},
#        {'content': 'year-on-year',
#         'span': {'offset': 1125, 'length': 12},
#         'confidence': 0.992,
#         'source': 'D(1,306,592,377,592,377,607,306,607)'},
#        {'content': 'primarily',
#         'span': {'offset': 1138, 'length': 9},
#         'confidence': 0.993,
#         'source': 'D(1,380,592,428,592,428,607,380,607)'},
#        {'content': 'due',
#         'span': {'offset': 1148, 'length': 3},
#         'confidence': 0.995,
#         'source': 'D(1,75,607,96,607,96,621,75,621)'},
#        {'content': 'to',
#         'span': {'offset': 1152, 'length': 2},
#         'confidence': 0.992,
#         'source': 'D(1,99,607,108,607,108,621,99,621)'},
#        {'content': 'fair',
#         'span': {'offset': 1155, 'length': 4},
#         'confidence': 0.989,
#         'source': 'D(1,111,607,130,607,130,621,111,621)'},
#        {'content': 'value',
#         'span': {'offset': 1160, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,132,607,161,607,161,621,132,621)'},
#        {'content': 'remeasurement',
#         'span': {'offset': 1166, 'length': 13},
#         'confidence': 0.992,
#         'source': 'D(1,164,607,250,607,250,621,164,621)'},
#        {'content': 'gains',
#         'span': {'offset': 1180, 'length': 5},
#         'confidence': 0.997,
#         'source': 'D(1,253,607,280,607,280,621,253,621)'},
#        {'content': 'related',
#         'span': {'offset': 1186, 'length': 7},
#         'confidence': 0.995,
#         'source': 'D(1,283,607,320,607,320,621,283,621)'},
#        {'content': 'to',
#         'span': {'offset': 1194, 'length': 2},
#         'confidence': 0.999,
#         'source': 'D(1,323,607,335,607,335,621,323,621)'},
#        {'content': 'the',
#         'span': {'offset': 1197, 'length': 3},
#         'confidence': 0.999,
#         'source': 'D(1,338,607,356,607,356,621,338,621)'},
#        {'content': 'mark-to-',
#         'span': {'offset': 1201, 'length': 8},
#         'confidence': 0.993,
#         'source': 'D(1,358,607,408,607,408,621,358,621)'},
#        {'content': 'market',
#         'span': {'offset': 1210, 'length': 6},
#         'confidence': 0.995,
#         'source': 'D(1,75,621,112,621,112,635,75,635)'},
#        {'content': 'movement',
#         'span': {'offset': 1217, 'length': 8},
#         'confidence': 0.993,
#         'source': 'D(1,115,621,173,621,173,635,115,635)'},
#        {'content': 'on',
#         'span': {'offset': 1226, 'length': 2},
#         'confidence': 0.998,
#         'source': 'D(1,176,621,188,621,188,635,176,635)'},
#        {'content': 'inflation-linked',
#         'span': {'offset': 1229, 'length': 16},
#         'confidence': 0.992,
#         'source': 'D(1,191,621,272,621,272,635,191,635)'},
#        {'content': 'swaps,',
#         'span': {'offset': 1246, 'length': 6},
#         'confidence': 0.99,
#         'source': 'D(1,275,621,311,621,311,635,275,635)'},
#        {'content': 'which',
#         'span': {'offset': 1253, 'length': 5},
#         'confidence': 0.998,
#         'source': 'D(1,314,621,345,621,345,635,314,635)'},
#        {'content': 'were',
#         'span': {'offset': 1259, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,348,621,375,621,375,635,348,635)'},
#        {'content': 'a',
#         'span': {'offset': 1264, 'length': 1},
#         'confidence': 0.987,
#         'source': 'D(1,378,621,384,621,384,635,378,635)'},
#        {'content': '£123m',
#         'span': {'offset': 1266, 'length': 5},
#         'confidence': 0.956,
#         'source': 'D(1,387,621,421,621,421,635,387,635)'},
#        {'content': 'benefit',
#         'span': {'offset': 1272, 'length': 7},
#         'confidence': 0.993,
#         'source': 'D(1,75,635,112,635,112,650,75,650)'},
#        {'content': 'this',
#         'span': {'offset': 1280, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,115,635,134,636,134,650,115,650)'},
#        {'content': 'year',
#         'span': {'offset': 1285, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,137,636,161,636,161,650,137,650)'},
#        {'content': 'compared',
#         'span': {'offset': 1290, 'length': 8},
#         'confidence': 0.993,
#         'source': 'D(1,163,636,219,636,219,651,163,650)'},
#        {'content': 'to',
#         'span': {'offset': 1299, 'length': 2},
#         'confidence': 0.992,
#         'source': 'D(1,222,636,232,636,232,650,222,651)'},
#        {'content': 'a',
#         'span': {'offset': 1302, 'length': 1},
#         'confidence': 0.995,
#         'source': 'D(1,235,636,242,636,242,650,235,650)'},
#        {'content': '£(214)m',
#         'span': {'offset': 1304, 'length': 7},
#         'confidence': 0.826,
#         'source': 'D(1,245,635,285,636,285,650,245,650)'},
#        {'content': 'charge',
#         'span': {'offset': 1312, 'length': 6},
#         'confidence': 0.996,
#         'source': 'D(1,288,636,322,636,322,651,288,650)'},
#        {'content': 'in',
#         'span': {'offset': 1319, 'length': 2},
#         'confidence': 0.996,
#         'source': 'D(1,325,636,337,636,337,650,325,651)'},
#        {'content': 'the',
#         'span': {'offset': 1322, 'length': 3},
#         'confidence': 0.999,
#         'source': 'D(1,340,636,356,636,356,650,340,650)'},
#        {'content': 'prior',
#         'span': {'offset': 1326, 'length': 5},
#         'confidence': 0.994,
#         'source': 'D(1,359,636,385,636,385,650,359,650)'},
#        {'content': 'year.',
#         'span': {'offset': 1332, 'length': 5},
#         'confidence': 0.992,
#         'source': 'D(1,388,636,416,636,416,651,388,650)'},
#        {'content': 'The',
#         'span': {'offset': 1338, 'length': 3},
#         'confidence': 0.998,
#         'source': 'D(1,75,650,93,650,93,665,75,665)'},
#        {'content': 'reduction',
#         'span': {'offset': 1342, 'length': 9},
#         'confidence': 0.992,
#         'source': 'D(1,96,650,148,650,148,665,96,665)'},
#        {'content': 'in',
#         'span': {'offset': 1352, 'length': 2},
#         'confidence': 0.996,
#         'source': 'D(1,150,650,162,650,162,665,150,665)'},
#        {'content': 'our',
#         'span': {'offset': 1355, 'length': 3},
#         'confidence': 0.995,
#         'source': 'D(1,165,650,183,650,183,665,165,665)'},
#        {'content': 'share',
#         'span': {'offset': 1359, 'length': 5},
#         'confidence': 0.996,
#         'source': 'D(1,186,650,215,650,215,665,186,665)'},
#        {'content': 'of',
#         'span': {'offset': 1365, 'length': 2},
#         'confidence': 0.998,
#         'source': 'D(1,218,650,229,650,229,665,218,665)'},
#        {'content': 'profit',
#         'span': {'offset': 1368, 'length': 6},
#         'confidence': 0.993,
#         'source': 'D(1,232,650,263,650,263,665,232,665)'},
#        {'content': 'from',
#         'span': {'offset': 1375, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,266,651,288,651,288,665,266,665)'},
#        {'content': 'joint',
#         'span': {'offset': 1380, 'length': 5},
#         'confidence': 0.996,
#         'source': 'D(1,293,651,317,651,317,665,293,665)'},
#        {'content': 'ventures',
#         'span': {'offset': 1386, 'length': 8},
#         'confidence': 0.994,
#         'source': 'D(1,320,651,368,651,368,665,320,665)'},
#        {'content': 'and',
#         'span': {'offset': 1395, 'length': 3},
#         'confidence': 0.996,
#         'source': 'D(1,370,651,392,651,392,665,370,665)'},
#        {'content': 'associates',
#         'span': {'offset': 1399, 'length': 10},
#         'confidence': 0.993,
#         'source': 'D(1,75,666,130,666,130,681,75,680)'},
#        {'content': 'was',
#         'span': {'offset': 1410, 'length': 3},
#         'confidence': 0.998,
#         'source': 'D(1,133,666,153,666,153,681,133,681)'},
#        {'content': 'principally',
#         'span': {'offset': 1414, 'length': 11},
#         'confidence': 0.994,
#         'source': 'D(1,156,666,211,666,211,681,156,681)'},
#        {'content': 'due',
#         'span': {'offset': 1426, 'length': 3},
#         'confidence': 0.995,
#         'source': 'D(1,214,666,233,666,233,681,214,681)'},
#        {'content': 'to',
#         'span': {'offset': 1430, 'length': 2},
#         'confidence': 0.999,
#         'source': 'D(1,236,666,248,666,248,681,236,681)'},
#        {'content': 'profit',
#         'span': {'offset': 1433, 'length': 6},
#         'confidence': 0.994,
#         'source': 'D(1,251,666,280,666,280,681,251,681)'},
#        {'content': 'from',
#         'span': {'offset': 1440, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,283,666,306,666,306,681,283,681)'},
#        {'content': 'Tesco',
#         'span': {'offset': 1445, 'length': 5},
#         'confidence': 0.997,
#         'source': 'D(1,313,666,344,666,344,680,313,681)'},
#        {'content': 'Underwriting',
#         'span': {'offset': 1451, 'length': 12},
#         'confidence': 0.995,
#         'source': 'D(1,348,666,417,666,417,681,348,680)'},
#        {'content': 'being',
#         'span': {'offset': 1487, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,470,339,497,339,497,355,470,355)'},
#        {'content': 'recognised',
#         'span': {'offset': 1493, 'length': 10},
#         'confidence': 0.992,
#         'source': 'D(1,500,339,559,339,559,355,500,355)'},
#        {'content': 'within',
#         'span': {'offset': 1504, 'length': 6},
#         'confidence': 0.994,
#         'source': 'D(1,562,339,595,339,595,355,562,355)'},
#        {'content': 'Tesco',
#         'span': {'offset': 1511, 'length': 5},
#         'confidence': 0.997,
#         'source': 'D(1,598,339,628,339,628,355,598,355)'},
#        {'content': 'Bank',
#         'span': {'offset': 1517, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,631,339,657,339,657,355,631,354)'},
#        {'content': 'operating',
#         'span': {'offset': 1522, 'length': 9},
#         'confidence': 0.993,
#         'source': 'D(1,660,339,710,339,710,355,660,355)'},
#        {'content': 'profit',
#         'span': {'offset': 1532, 'length': 6},
#         'confidence': 0.994,
#         'source': 'D(1,713,339,743,339,743,355,713,355)'},
#        {'content': 'following',
#         'span': {'offset': 1539, 'length': 9},
#         'confidence': 0.993,
#         'source': 'D(1,746,339,792,339,792,355,746,355)'},
#        {'content': 'its',
#         'span': {'offset': 1549, 'length': 3},
#         'confidence': 0.995,
#         'source': 'D(1,795,339,812,340,812,354,795,355)'},
#        {'content': 'full',
#         'span': {'offset': 1553, 'length': 4},
#         'confidence': 0.993,
#         'source': 'D(1,470,354,487,354,487,369,470,369)'},
#        {'content': 'acquisition',
#         'span': {'offset': 1558, 'length': 11},
#         'confidence': 0.992,
#         'source': 'D(1,490,354,545,354,545,369,490,369)'},
#        {'content': 'in',
#         'span': {'offset': 1570, 'length': 2},
#         'confidence': 0.995,
#         'source': 'D(1,548,354,558,354,558,369,548,369)'},
#        {'content': 'May.',
#         'span': {'offset': 1573, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,560,354,586,354,586,369,561,369)'},
#        {'content': 'The',
#         'span': {'offset': 1578, 'length': 3},
#         'confidence': 0.997,
#         'source': 'D(1,589,354,607,354,607,369,589,369)'},
#        {'content': 'increase',
#         'span': {'offset': 1582, 'length': 8},
#         'confidence': 0.992,
#         'source': 'D(1,610,354,654,355,654,369,610,369)'},
#        {'content': 'in',
#         'span': {'offset': 1591, 'length': 2},
#         'confidence': 0.995,
#         'source': 'D(1,657,355,669,355,669,369,657,369)'},
#        {'content': 'tax',
#         'span': {'offset': 1594, 'length': 3},
#         'confidence': 0.995,
#         'source': 'D(1,672,355,686,355,686,369,672,369)'},
#        {'content': 'this',
#         'span': {'offset': 1598, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,689,355,709,355,709,369,689,369)'},
#        {'content': 'year',
#         'span': {'offset': 1603, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,711,355,735,355,735,369,711,369)'},
#        {'content': 'primarily',
#         'span': {'offset': 1608, 'length': 9},
#         'confidence': 0.992,
#         'source': 'D(1,738,355,783,355,783,369,738,369)'},
#        {'content': 'reflects',
#         'span': {'offset': 1618, 'length': 8},
#         'confidence': 0.989,
#         'source': 'D(1,786,355,831,355,831,369,786,369)'},
#        {'content': 'higher',
#         'span': {'offset': 1627, 'length': 6},
#         'confidence': 0.995,
#         'source': 'D(1,470,369,501,369,501,384,470,384)'},
#        {'content': 'levels',
#         'span': {'offset': 1634, 'length': 6},
#         'confidence': 0.993,
#         'source': 'D(1,504,369,533,369,533,384,504,384)'},
#        {'content': 'of',
#         'span': {'offset': 1641, 'length': 2},
#         'confidence': 0.998,
#         'source': 'D(1,536,369,546,369,546,384,536,384)'},
#        {'content': 'both',
#         'span': {'offset': 1644, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,549,369,573,369,573,384,549,384)'},
#        {'content': 'retail',
#         'span': {'offset': 1649, 'length': 6},
#         'confidence': 0.989,
#         'source': 'D(1,576,369,604,369,604,384,576,384)'},
#        {'content': 'and',
#         'span': {'offset': 1656, 'length': 3},
#         'confidence': 0.999,
#         'source': 'D(1,607,369,625,369,625,384,607,384)'},
#        {'content': 'Tesco',
#         'span': {'offset': 1660, 'length': 5},
#         'confidence': 0.995,
#         'source': 'D(1,627,369,657,369,657,384,627,384)'},
#        {'content': 'Bank',
#         'span': {'offset': 1666, 'length': 4},
#         'confidence': 0.992,
#         'source': 'D(1,660,369,685,369,685,384,660,384)'},
#        {'content': 'operating',
#         'span': {'offset': 1671, 'length': 9},
#         'confidence': 0.992,
#         'source': 'D(1,688,369,737,370,737,384,688,384)'},
#        {'content': 'profit,',
#         'span': {'offset': 1681, 'length': 7},
#         'confidence': 0.993,
#         'source': 'D(1,740,370,770,370,770,384,740,384)'},
#        {'content': 'in',
#         'span': {'offset': 1689, 'length': 2},
#         'confidence': 0.997,
#         'source': 'D(1,773,370,784,370,784,384,773,384)'},
#        {'content': 'addition',
#         'span': {'offset': 1692, 'length': 8},
#         'confidence': 0.994,
#         'source': 'D(1,786,370,831,370,831,384,786,384)'},
#        {'content': 'to',
#         'span': {'offset': 1701, 'length': 2},
#         'confidence': 0.998,
#         'source': 'D(1,470,384,483,384,483,398,470,398)'},
#        {'content': 'the',
#         'span': {'offset': 1704, 'length': 3},
#         'confidence': 0.999,
#         'source': 'D(1,486,384,501,384,501,398,486,398)'},
#        {'content': 'revaluation',
#         'span': {'offset': 1708, 'length': 11},
#         'confidence': 0.993,
#         'source': 'D(1,504,384,565,384,565,398,504,398)'},
#        {'content': 'of',
#         'span': {'offset': 1720, 'length': 2},
#         'confidence': 0.992,
#         'source': 'D(1,568,384,578,384,578,398,568,398)'},
#        {'content': 'deferred',
# ...
#         'span': {'offset': 3998, 'length': 9},
#         'elements': ['/paragraphs/53']},
#        {'kind': 'content',
#         'rowIndex': 11,
#         'columnIndex': 1,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '£(510)m',
#         'source': 'D(1,509,866,587,866,587,880,509,880)',
#         'span': {'offset': 4017, 'length': 7},
#         'elements': ['/paragraphs/54']},
#        {'kind': 'content',
#         'rowIndex': 11,
#         'columnIndex': 2,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '£(104)m',
#         'source': 'D(1,587,866,681,866,681,880,587,880)',
#         'span': {'offset': 4034, 'length': 7},
#         'elements': ['/paragraphs/55']},
#        {'kind': 'content',
#         'rowIndex': 11,
#         'columnIndex': 3,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,681,866,757,866,757,880,681,880)',
#         'span': {'offset': 4051, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 11,
#         'columnIndex': 4,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,757,866,836,866,836,880,757,880)',
#         'span': {'offset': 4061, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 12,
#         'columnIndex': 0,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': 'Group statutory profit after tax',
#         'source': 'D(1,63,880,509,880,509,900,63,900)',
#         'span': {'offset': 4082, 'length': 32},
#         'elements': ['/paragraphs/56']},
#        {'kind': 'content',
#         'rowIndex': 12,
#         'columnIndex': 1,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '£1,523m',
#         'source': 'D(1,509,880,587,880,587,900,509,900)',
#         'span': {'offset': 4124, 'length': 7},
#         'elements': ['/paragraphs/57']},
#        {'kind': 'content',
#         'rowIndex': 12,
#         'columnIndex': 2,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '£532m',
#         'source': 'D(1,587,880,681,880,681,900,587,900)',
#         'span': {'offset': 4141, 'length': 5},
#         'elements': ['/paragraphs/58']},
#        {'kind': 'content',
#         'rowIndex': 12,
#         'columnIndex': 3,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '186.3%',
#         'source': 'D(1,681,880,757,880,757,900,681,900)',
#         'span': {'offset': 4156, 'length': 6},
#         'elements': ['/paragraphs/59']},
#        {'kind': 'content',
#         'rowIndex': 12,
#         'columnIndex': 4,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,757,880,836,880,836,900,757,900)',
#         'span': {'offset': 4172, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 13,
#         'columnIndex': 0,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': 'Adjusted diluted EPS(4.',
#         'source': 'D(1,63,900,509,900,509,916,63,916)',
#         'span': {'offset': 4193, 'length': 23},
#         'elements': ['/paragraphs/60']},
#        {'kind': 'content',
#         'rowIndex': 13,
#         'columnIndex': 1,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '21.86p',
#         'source': 'D(1,509,900,587,900,587,916,509,916)',
#         'span': {'offset': 4226, 'length': 6},
#         'elements': ['/paragraphs/61']},
#        {'kind': 'content',
#         'rowIndex': 13,
#         'columnIndex': 2,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '11.58p',
#         'source': 'D(1,587,900,681,900,681,916,587,916)',
#         'span': {'offset': 4242, 'length': 6},
#         'elements': ['/paragraphs/62']},
#        {'kind': 'content',
#         'rowIndex': 13,
#         'columnIndex': 3,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '88.8%',
#         'source': 'D(1,681,900,757,900,757,916,681,916)',
#         'span': {'offset': 4258, 'length': 5},
#         'elements': ['/paragraphs/63']},
#        {'kind': 'content',
#         'rowIndex': 13,
#         'columnIndex': 4,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,757,900,836,900,836,916,757,916)',
#         'span': {'offset': 4273, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 14,
#         'columnIndex': 0,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': 'Statutory diluted EPS',
#         'source': 'D(1,63,916,509,916,509,931,63,931)',
#         'span': {'offset': 4294, 'length': 21},
#         'elements': ['/paragraphs/64']},
#        {'kind': 'content',
#         'rowIndex': 14,
#         'columnIndex': 1,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '19.64p',
#         'source': 'D(1,509,916,587,916,587,931,509,931)',
#         'span': {'offset': 4325, 'length': 6},
#         'elements': ['/paragraphs/65']},
#        {'kind': 'content',
#         'rowIndex': 14,
#         'columnIndex': 2,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '5.58p',
#         'source': 'D(1,587,916,681,916,681,931,587,931)',
#         'span': {'offset': 4341, 'length': 5},
#         'elements': ['/paragraphs/66']},
#        {'kind': 'content',
#         'rowIndex': 14,
#         'columnIndex': 3,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '252.0%',
#         'source': 'D(1,681,916,757,916,757,931,681,931)',
#         'span': {'offset': 4356, 'length': 6},
#         'elements': ['/paragraphs/67']},
#        {'kind': 'content',
#         'rowIndex': 14,
#         'columnIndex': 4,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,757,916,836,916,836,931,757,931)',
#         'span': {'offset': 4372, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 15,
#         'columnIndex': 0,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': 'Dividend per share',
#         'source': 'D(1,63,931,509,931,509,946,63,946)',
#         'span': {'offset': 4393, 'length': 18},
#         'elements': ['/paragraphs/68']},
#        {'kind': 'content',
#         'rowIndex': 15,
#         'columnIndex': 1,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '10.90р',
#         'source': 'D(1,509,931,587,931,587,946,509,946)',
#         'span': {'offset': 4421, 'length': 6},
#         'elements': ['/paragraphs/69']},
#        {'kind': 'content',
#         'rowIndex': 15,
#         'columnIndex': 2,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '9.15p',
#         'source': 'D(1,587,931,681,931,681,946,587,946)',
#         'span': {'offset': 4437, 'length': 5},
#         'elements': ['/paragraphs/70']},
#        {'kind': 'content',
#         'rowIndex': 15,
#         'columnIndex': 3,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '19.1%',
#         'source': 'D(1,681,931,757,931,757,946,681,946)',
#         'span': {'offset': 4452, 'length': 5},
#         'elements': ['/paragraphs/71']},
#        {'kind': 'content',
#         'rowIndex': 15,
#         'columnIndex': 4,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,757,931,836,931,836,946,757,946)',
#         'span': {'offset': 4467, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 16,
#         'columnIndex': 0,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': 'Net debt™1,11',
#         'source': 'D(1,63,946,509,946,509,962,62,961)',
#         'span': {'offset': 4488, 'length': 13},
#         'elements': ['/paragraphs/72']},
#        {'kind': 'content',
#         'rowIndex': 16,
#         'columnIndex': 1,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '£(10.5)bn',
#         'source': 'D(1,509,946,587,946,587,962,509,962)',
#         'span': {'offset': 4511, 'length': 9},
#         'elements': ['/paragraphs/73']},
#        {'kind': 'content',
#         'rowIndex': 16,
#         'columnIndex': 2,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '£(12.0)bn',
#         'source': 'D(1,587,946,681,946,681,962,587,962)',
#         'span': {'offset': 4530, 'length': 9},
#         'elements': ['/paragraphs/74']},
#        {'kind': 'content',
#         'rowIndex': 16,
#         'columnIndex': 3,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,681,946,757,946,757,962,681,962)',
#         'span': {'offset': 4549, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 16,
#         'columnIndex': 4,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,757,946,836,946,836,962,757,962)',
#         'span': {'offset': 4559, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 17,
#         'columnIndex': 0,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': 'Retail free cash flow"',
#         'source': 'D(1,62,961,509,962,509,978,62,977)',
#         'span': {'offset': 4580, 'length': 22},
#         'elements': ['/paragraphs/75']},
#        {'kind': 'content',
#         'rowIndex': 17,
#         'columnIndex': 1,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '£2.3bn',
#         'source': 'D(1,509,962,587,962,587,978,509,978)',
#         'span': {'offset': 4612, 'length': 6},
#         'elements': ['/paragraphs/76']},
#        {'kind': 'content',
#         'rowIndex': 17,
#         'columnIndex': 2,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '£1.3bn',
#         'source': 'D(1,587,962,681,962,681,978,587,978)',
#         'span': {'offset': 4628, 'length': 6},
#         'elements': ['/paragraphs/77']},
#        {'kind': 'content',
#         'rowIndex': 17,
#         'columnIndex': 3,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,681,962,757,962,757,978,681,978)',
#         'span': {'offset': 4644, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 17,
#         'columnIndex': 4,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,757,962,836,962,836,978,757,978)',
#         'span': {'offset': 4654, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 18,
#         'columnIndex': 0,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': 'Capex1)',
#         'source': 'D(1,62,977,509,978,509,992,62,990)',
#         'span': {'offset': 4675, 'length': 7},
#         'elements': ['/paragraphs/78']},
#        {'kind': 'content',
#         'rowIndex': 18,
#         'columnIndex': 1,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '£1.1bn',
#         'source': 'D(1,509,978,587,978,587,992,509,992)',
#         'span': {'offset': 4692, 'length': 6},
#         'elements': ['/paragraphs/79']},
#        {'kind': 'content',
#         'rowIndex': 18,
#         'columnIndex': 2,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '£1.0bn',
#         'source': 'D(1,587,978,681,978,681,992,587,992)',
#         'span': {'offset': 4708, 'length': 6},
#         'elements': ['/paragraphs/80']},
#        {'kind': 'content',
#         'rowIndex': 18,
#         'columnIndex': 3,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,681,978,757,978,757,992,681,992)',
#         'span': {'offset': 4724, 'length': 0}},
#        {'kind': 'content',
#         'rowIndex': 18,
#         'columnIndex': 4,
#         'rowSpan': 1,
#         'columnSpan': 1,
#         'content': '',
#         'source': 'D(1,757,978,836,978,836,992,757,992)',
#         'span': {'offset': 4734, 'length': 0}}],
#       'source': 'D(1,73,687,832,687,832,995,73,995)',
#       'span': {'offset': 2816, 'length': 4815},
#       'footnotes': [{'content': "(a) The Group has defined and outlined the purpose of its alternative performance measures, Including its performance highlights, in the Glossary starting on page 207. During the year, the operating profit and EPS APMs were renamed. Profit has changed from 'Group operating profit before exceptional items and amortisation of acquired intangibles' to 'Adjusted operating profit'. EPS has changed from 'Diluted EPS before exceptional and other Items' to 'Adjusted diluted EPS'. The definitions are unchanged. The Retall free cash flow APM was amended in order to provide a more consistent and predictable view of free cash flow generated by the Group's retal operation. 'Exceptional items and amortisation of acquired intangibles' within operating profit, along with net pension finance costs, fair value remeasurements of financial instruments, and the tax impact of such items (below operating profit), are now called 'Adjusting Items'. The policy for determining adjusting items, and the Items adjusted for, are unchanged from the prior year and hence there is no Impact on previously reported APMs.",
#         'source': 'D(1,76,1002,825,1003,825,1068,76,1067)',
#         'span': {'offset': 4756, 'length': 1102},
#         'elements': ['/paragraphs/81']},
#        {'content': '(b) All measures apart from Net debt are shown on a continuing operations basis unless otherwise stated. Further details on discontinued operations can be found in Note 7, starting on page 140.',
#         'source': 'D(1,76,1066,811,1066,811,1077,76,1078)',
#         'span': {'offset': 5858, 'length': 195},
#         'elements': ['/paragraphs/82']},
#        {'content': "[c) The Group has changed its accounting policy for property buybacks In light of an evolution of accepted practice In relation to the application of IFRS 16 'Leases' to such transactions. Comparatives have been restated for this change in accounting policy (see Note 1 on page 122 for further details).",
#         'source': 'D(1,76,1077,828,1077,828,1100,76,1100)',
#         'span': {'offset': 6053, 'length': 305},
#         'elements': ['/paragraphs/83']},
#        {'content': '(d) Group sales exclude VAT and fuel. Sales change shown on a comparable days basis for Central Europe.',
#         'source': 'D(1,75,1098,494,1098,494,1109,75,1109)',
#         'span': {'offset': 6358, 'length': 105},
#         'elements': ['/paragraphs/84']},
#        {'content': '[e) Adjusted operating profit and Adjusted diluted EPS exclude Adjusting items as noted in footnote (a).',
#         'source': 'D(1,76,1109,483,1109,483,1120,76,1120)',
#         'span': {'offset': 6463, 'length': 106},
#         'elements': ['/paragraphs/85']},
#        {'content': '(f) Net debt and Retall free cash flow exclude Tesco Bank.',
#         'source': 'D(1,75,1120,306,1120,306,1131,75,1131)',
#         'span': {'offset': 6569, 'length': 60},
#         'elements': ['/paragraphs/86']},
#        {'content': '(g) The share base used in Adjusted diluted EPS In the prior year is adjusted to capture the full Impact of the share consolidation which followed the sale of our businesses in Thailand and Malaysia, as if it took place at the start of the 2020/21 financial year. As such, Adjusted diluted EPS (adjusted for share consolidation) Is presented on a basis other than In accordance with IAS 33. Please see page 210 for a reconciliation to Adjusted diluted EPS. Like-for-like Is a measure of growth in Group online sales and sales from stores that have been open for at least a year (at constant exchange rates, excluding VAT and fuel).',
#         'source': 'D(1,76,1130,829,1130,829,1173,76,1174)',
#         'span': {'offset': 6629, 'length': 633},
#         'elements': ['/paragraphs/87']},
#        {'content': '(h) Like-for-like is a measure of growth in Group online sales and sales from stores that have been open for at least a year (at constant exchange rates, excluding VAT and fuel).',
#         'source': 'D(1,75,1173,769,1173,769,1184,75,1184)',
#         'span': {'offset': 7262, 'length': 180},
#         'elements': ['/paragraphs/88']},
#        {'content': '() Capex excludes additions arising from business combinations and buybacks of properties (typically stores), as well as additions relating to decommissioning provisions and similar items.',
#         'source': 'D(1,76,1184,817,1183,817,1194,76,1195)',
#         'span': {'offset': 7442, 'length': 190},
#         'elements': ['/paragraphs/89']}]}],
#     'figures': [{'source': 'D(1,470,52,830,52,830,305,469,305)',
#       'span': {'offset': 1466, 'length': 18},
#       'id': '1.1'}]}]}]

# %% [markdown]
# # Organize multimodal data
# This is a simple starting point. Feel free to give your own chunking strategies a try!

# %% [markdown]
# ### Preprocess JSON output data

# %%
def convert_values_to_strings(json_obj):
    return [str(value) for value in json_obj]

#process all content and convert to string      
def process_allJSON_content(all_content):

    # Initialize empty list to store string of all content
    output = []

    document_splits = [
        "This is a json string representing a document with text and metadata for the file located in "+str(analyzer_configs[0]["location"])+" "
        + v 
        + "```"
        for v in convert_values_to_strings(all_content[0]["content"])
    ]
    docs = [Document(page_content=v) for v in document_splits]
    output += docs  
    
    return output

all_splits = process_allJSON_content(analyzer_content)

print("There are " + str(len(all_splits)) + " documents.") 
# Print the content of all doc splits
for doc in all_splits:
    print(f"doc content", doc.page_content)
# Out:
# There are 1 documents.
# doc content This is a json string representing a document with text and metadata for the file located in data/tesco/TESCO - FY22.pdf {'markdown': '<!-- PageHeader="Strategic report" -->\n<!-- PageHeader="Financial review" -->\n\n\n# Group review of performance.\n\nGroup sales increased by +3.0% at constant rates, with growth\nacross all regions on top of exceptionally strong sales last year.\nRevenue increased by +6.4% at constant rates including fuel sales\ngrowth of +48.1% as customers travelled more following the easing\nof government restrictions. While two-year like-for-like" fuel sales\ngrowth was negative at (6.4)%, this primarily reflects lower demand\nin the first half, with fuel sales ahead of pre-pandemic levels by the\nend of the year.\n\nGroup adjusted operating profit* grew by +58.9% at constant rates,\nreflecting the strong sales performance across the retail businesses,\na reduction in COVID-19 related costs and a return to profitability\nin Tesco Bank. These benefits were partially offset by inflationary\npressures in the cost base, particularly in distribution costs. Group\nstatutory operating profit, which includes adjusting items related to\nthe costs of historical shareholder litigation claims, grew by +65.5%.\n\nFinance income and finance costs reduced year-on-year primarily\ndue to fair value remeasurement gains related to the mark-to-\nmarket movement on inflation-linked swaps, which were a £123m\nbenefit this year compared to a £(214)m charge in the prior year.\nThe reduction in our share of profit from joint ventures and\nassociates was principally due to profit from Tesco Underwriting\n\n\n<figure>\n</figure>\n\n\nbeing recognised within Tesco Bank operating profit following its\nfull acquisition in May. The increase in tax this year primarily reflects\nhigher levels of both retail and Tesco Bank operating profit, in addition\nto the revaluation of deferred tax relating to the announced change\nin the UK corporation tax rate from 19% to 25%, effective 1 April 2023.\n\nOur adjusted diluted EPSlø rose by +88.8%, reflecting the increase\nin retail and Tesco Bank operating profit and a reduction in net\nfinance costs. We have proposed a final dividend of 7.70 pence\nper ordinary share, taking the full-year dividend to 10.90 pence\nper ordinary share, an increase of 19.1% year-on-year.\n\nNet debtlt1.00 reduced by £1.4bn year-on-year, primarily driven by\nstrong free cash flow generation. Retail free cash flow" increased\nby £0.9bn year-on-year due to higher retail operating profits, the\nelimination of UK pension contributions (following the £2.5bn one-off\ncontribution last year from the Asia disposal proceeds) and a working\ncapital benefit from higher sales. These benefits were partly offset\nby an increase in capital expenditure. The Net debt/EBITDA ratio was\n2.5 times at the year end, compared to 3.3 times last year.\n\nFurther commentary on all of these metrics can be found below and\na full income statement can be found on page 116.\n\n\n<table>\n<tr>\n<th rowspan="2">52 weeks ended 26 February 202221</th>\n<th rowspan="2">FY 2021/22</th>\n<th rowspan="2">FY0 2020/21</th>\n<th colspan="2">Total change YoY</th>\n</tr>\n<tr>\n<th>Actual rate</th>\n<th>Constant rate</th>\n</tr>\n<tr>\n<td>Group sales (exc. VAT, exc. fuel)(d)</td>\n<td>£54,768m</td>\n<td>£53,445m</td>\n<td>2.5%</td>\n<td>3.0%</td>\n</tr>\n<tr>\n<td>Fuel</td>\n<td>£6,576m</td>\n<td>£4,442m</td>\n<td>48.1%</td>\n<td>48.1%</td>\n</tr>\n<tr>\n<td>Revenue (exc. VAT, inc. fuel)</td>\n<td>£61,344m</td>\n<td>£57,887m</td>\n<td>6.0%</td>\n<td>6.4%</td>\n</tr>\n<tr>\n<td>Adjusted operating profit **</td>\n<td>£2,825m</td>\n<td>£1,788m</td>\n<td>58.0%</td>\n<td>58.9%</td>\n</tr>\n<tr>\n<td>Adjusting items</td>\n<td>£(265)m</td>\n<td>£(241)m</td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td>Group statutory operating profit</td>\n<td>£2,560m</td>\n<td>£1,547m</td>\n<td>65.5%</td>\n<td></td>\n</tr>\n<tr>\n<td>Net finance costs</td>\n<td>£(542)m</td>\n< ...

# %% [markdown]
# ##### *Optional* - Split document markdown into semantic chunks

# %%
# Configure langchain text splitting settings
EMBEDDING_CHUNK_SIZE = 512
EMBEDDING_CHUNK_OVERLAP = 20

# Split the document into chunks base on markdown headers.
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]

text_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

docs_string = analyzer_content[0]['content'][0]['markdown'] #extract document analyzer markdown (first item in the list) is the document analyzer markdown output
docs_splits = text_splitter.split_text(docs_string)

print("Length of splits: " + str(len(docs_splits)))

# %% [markdown]
# # Embed and index the chunks

# %%
# Embed the splitted documents and insert into Azure Search vector store
def embed_and_index_chunks(docs):
    aoai_embeddings = AzureOpenAIEmbeddings(
        azure_deployment=AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME,
        openai_api_version=AZURE_OPENAI_EMBEDDING_API_VERSION,  # e.g., "2023-12-01-preview"
        azure_endpoint=AZURE_OPENAI_ENDPOINT,
        azure_ad_token_provider=token_provider
    )

    vector_store: AzureSearch = AzureSearch(
        azure_search_endpoint=AZURE_SEARCH_ENDPOINT,
        azure_search_key=None,
        index_name=AZURE_SEARCH_INDEX_NAME,
        embedding_function=aoai_embeddings.embed_query
    )
    vector_store.add_documents(documents=docs)
    return vector_store


# embed and index the docs:
vector_store = embed_and_index_chunks(all_splits)

# %% [markdown]
# # Retrieve relevant chunks based on a question
# #### Execute a pure vector similarity search

# %%
# Set your query
query = "what's the total revenue"

# %%
# Perform a similarity search
aoai_embeddings = AzureOpenAIEmbeddings(
    azure_deployment=AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME,
    openai_api_version=AZURE_OPENAI_EMBEDDING_API_VERSION,  # e.g., "2023-12-01-preview"
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    azure_ad_token_provider=token_provider
)
vector_store1 = AzureSearch(
    azure_search_endpoint=AZURE_SEARCH_ENDPOINT,
    azure_search_key=None,
    index_name="tesco_report_agent",
    embedding_function=aoai_embeddings.embed_query
)
docs = vector_store1.similarity_search(
    query=query,
    k=3,
    search_type="similarity",
)
for doc in docs:
    print(doc.page_content)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 14
#       2 aoai_embeddings = AzureOpenAIEmbeddings(
#       3     azure_deployment=AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME,
#       4     openai_api_version=AZURE_OPENAI_EMBEDDING_API_VERSION,  # e.g., "2023-12-01-preview"
#       5     azure_endpoint=AZURE_OPENAI_ENDPOINT,
#       6     azure_ad_token_provider=token_provider
#       7 )
#       8 vector_store1 = AzureSearch(
#       9     azure_search_endpoint=AZURE_SEARCH_ENDPOINT,
#      10     azure_search_key=None,
#      11     index_name="tesco_report_agent",
#      12     embedding_function=aoai_embeddings.embed_query
#      13 )
# ---> 14 docs = vector_store1.similarity_search(
#      15     query=query,
#      16     k=3,
#      17     search_type="similarity",
#      18 )
#      19 for doc in docs:
#      20     print(doc.page_content)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/langchain_community/vectorstores/azuresearch.py:765, in AzureSearch.similarity_search(self, query, k, search_type, **kwargs)
#     763 search_type = search_type or self.search_type
#     764 if search_type == "similarity":
# --> 765     docs = self.vector_search(query, k=k, **kwargs)
#     766 elif search_type == "hybrid":
#     767     docs = self.hybrid_search(query, k=k, **kwargs)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/langchain_community/vectorstores/azuresearch.py:865, in AzureSearch.vector_search(self, query, k, filters, **kwargs)
#     852 def vector_search(
#     853     self, query: str, k: int = 4, *, filters: Optional[str] = None, **kwargs: Any
#     854 ) -> List[Document]:
#     855     """
#     856     Returns the most similar indexed documents to the query text.
#     857
#    (...)    863         List[Document]: A list of documents that are most similar to the query text.
#     864     """
# --> 865     docs_and_scores = self.vector_search_with_score(query, k=k, filters=filters)
#     866     return [doc for doc, _ in docs_and_scores]
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/langchain_community/vectorstores/azuresearch.py:907, in AzureSearch.vector_search_with_score(self, query, k, filters, **kwargs)
#     904 embedding = self.embed_query(query)
#     905 results = self._simple_search(embedding, "", k, filters=filters, **kwargs)
# --> 907 return _results_to_documents(results)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/langchain_community/vectorstores/azuresearch.py:1825, in _results_to_documents(results)
#    1822 def _results_to_documents(
#    1823     results: SearchItemPaged[Dict],
#    1824 ) -> List[Tuple[Document, float]]:
# -> 1825     docs = [
#    1826         (
#    1827             _result_to_document(result),
#    1828             float(result["@search.score"]),
#    1829         )
#    1830         for result in results
#    1831     ]
#    1832     return docs
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/langchain_community/vectorstores/azuresearch.py:1825, in <listcomp>(.0)
#    1822 def _results_to_documents(
#    1823     results: SearchItemPaged[Dict],
#    1824 ) -> List[Tuple[Document, float]]:
# -> 1825     docs = [
#    1826         (
#    1827             _result_to_document(result),
#    1828             float(result["@search.score"]),
#    1829         )
#    1830         for result in results
#    1831     ]
#    1832     return docs
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/search/documents/_paging.py:54, in SearchItemPaged.__next__(self)
#      52     first_iterator = self._first_iterator_instance()
#      53     self._page_iterator = itertools.chain.from_iterable(first_iterator)
# ---> 54 return next(self._page_iterator)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/paging.py:82, in PageIterator.__next__(self)
#      80     raise StopIteration("End of paging")
#      81 try:
# ---> 82     self._response = self._get_next(self.continuation_token)
#      83 except AzureError as error:
#      84     if not error.continuation_token:
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/search/documents/_paging.py:125, in SearchPageIterator._get_next_cb(self, continuation_token)
#     123 def _get_next_cb(self, continuation_token):
#     124     if continuation_token is None:
# --> 125         return self._client.documents.search_post(search_request=self._initial_query.request, **self._kwargs)
#     127     _next_link, next_page_request = unpack_continuation_token(continuation_token)
#     129     return self._client.documents.search_post(search_request=next_page_request, **self._kwargs)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/tracing/decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/search/documents/_generated/operations/_documents_operations.py:745, in DocumentsOperations.search_post(self, search_request, request_options, **kwargs)
#     742 _request.url = self._client.format_url(_request.url, **path_format_arguments)
#     744 _stream = False
# --> 745 pipeline_response: PipelineResponse = self._client._pipeline.run(  # pylint: disable=protected-access
#     746     _request, stream=_stream, **kwargs
#     747 )
#     749 response = pipeline_response.http_response
#     751 if response.status_code not in [200, 206]:
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:242, in Pipeline.run(self, request, **kwargs)
#     240 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     241 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 242 return first_node.send(pipeline_request)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 98 (2 times)]
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/pipeline/policies/_redirect.py:205, in RedirectPolicy.send(self, request)
#     203 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     204 while retryable:
# --> 205     response = self.next.send(request)
#     206     redirect_location = self.get_redirect_location(response)
#     207     if redirect_location and redirect_settings["allow"]:
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/pipeline/policies/_retry.py:545, in RetryPolicy.send(self, request)
#     543 self._configure_timeout(request, absolute_timeout, is_response_error)
#     544 request.context["retry_count"] = len(retry_settings["history"])
# --> 545 response = self.next.send(request)
#     546 if self.is_retry(retry_settings, response):
#     547     retry_active = self.increment(retry_settings, response=response)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/pipeline/policies/_authentication.py:157, in BearerTokenCredentialPolicy.send(self, request)
#     149 def send(self, request: PipelineRequest[HTTPRequestType]) -> PipelineResponse[HTTPRequestType, HTTPResponseType]:
#     150     """Authorize request with a bearer token and send it to the next policy
#     151
#     152     :param request: The pipeline request object
#    (...)    155     :rtype: ~azure.core.pipeline.PipelineResponse
#     156     """
# --> 157     self.on_request(request)
#     158     try:
#     159         response = self.next.send(request)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/pipeline/policies/_authentication.py:132, in BearerTokenCredentialPolicy.on_request(self, request)
#     129 self._enforce_https(request)
#     131 if self._token is None or self._need_new_token:
# --> 132     self._request_token(*self._scopes)
#     133 bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#     134 self._update_headers(request.http_request.headers, bearer_token)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/pipeline/policies/_authentication.py:108, in _BearerTokenCredentialPolicyBase._request_token(self, *scopes, **kwargs)
#     101 def _request_token(self, *scopes: str, **kwargs: Any) -> None:
#     102     """Request a new token from the credential.
#     103
#     104     This will call the credential's appropriate method to get a token and store it in the policy.
#     105
#     106     :param str scopes: The type of access needed.
#     107     """
# --> 108     self._token = self._get_token(*scopes, **kwargs)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/core/pipeline/policies/_authentication.py:98, in _BearerTokenCredentialPolicyBase._get_token(self, *scopes, **kwargs)
#      95         if key in TokenRequestOptions.__annotations__:  # pylint: disable=no-member
#      96             options[key] = kwargs.pop(key)  # type: ignore[literal-required]
# ---> 98     return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#      99 return cast(TokenCredential, self._credential).get_token(*scopes, **kwargs)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/identity/_credentials/default.py:270, in DefaultAzureCredential.get_token_info(self, options, *scopes)
#     253 """Request an access token for `scopes`.
#     254
#     255 This is an alternative to `get_token` to enable certain scenarios that require additional properties
#    (...)    267    `message` attribute listing each authentication attempt and its error message.
#     268 """
#     269 if self._successful_credential:
# --> 270     token_info = cast(SupportsTokenInfo, self._successful_credential).get_token_info(*scopes, options=options)
#     271     _LOGGER.info(
#     272         "%s acquired a token from %s", self.__class__.__name__, self._successful_credential.__class__.__name__
#     273     )
#     274     return token_info
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/identity/_internal/decorators.py:23, in log_get_token.<locals>.wrapper(*args, **kwargs)
#      20 @functools.wraps(fn)
#      21 def wrapper(*args, **kwargs):
#      22     try:
# ---> 23         token = fn(*args, **kwargs)
#      24         _LOGGER.log(
#      25             logging.DEBUG if within_credential_chain.get() else logging.INFO,
#      26             "%s succeeded",
#      27             fn.__qualname__,
#      28         )
#      29         if _LOGGER.isEnabledFor(logging.DEBUG):
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/identity/_credentials/azure_cli.py:143, in AzureCliCredential.get_token_info(self, options, *scopes)
#     123 @log_get_token
#     124 def get_token_info(self, *scopes: str, options: Optional[TokenRequestOptions] = None) -> AccessTokenInfo:
#     125     """Request an access token for `scopes`.
#     126
#     127     This is an alternative to `get_token` to enable certain scenarios that require additional properties
#    (...)    141       receive an access token.
#     142     """
# --> 143     return self._get_token_base(*scopes, options=options)
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/identity/_credentials/azure_cli.py:168, in AzureCliCredential._get_token_base(self, options, *scopes, **kwargs)
#     166 if self.subscription:
#     167     command_args += ["--subscription", self.subscription]
# --> 168 output = _run_command(command_args, self._process_timeout)
#     170 token = parse_token(output)
#     171 if not token:
#
# File ~/Desktop/coding/hackathon_fa_agents/.venv/lib/python3.11/site-packages/azure/identity/_credentials/azure_cli.py:254, in _run_command(command_args, timeout)
#     245     kwargs: Dict[str, Any] = {
#     246         "stderr": subprocess.PIPE,
#     247         "stdin": subprocess.DEVNULL,
#    (...)    251         "env": dict(os.environ, AZURE_CORE_NO_COLOR="true"),
#     252     }
#     253     _LOGGER.debug("Executing subprocess with the following arguments %s", args)
# --> 254     return subprocess.check_output(args, **kwargs)
#     255 except subprocess.CalledProcessError as ex:
#     256     # non-zero return from shell
#     257     # Fallback check in case the executable is not found while executing subprocess.
#     258     if ex.returncode == 127 or (ex.stderr is not None and ex.stderr.startswith("'az' is not recognized")):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1207, in Popen.communicate(self, input, timeout)
#    1204     endtime = None
#    1206 try:
# -> 1207     stdout, stderr = self._communicate(input, endtime, timeout)
#    1208 except KeyboardInterrupt:
#    1209     # https://bugs.python.org/issue25942
#    1210     # See the detailed comment in .wait().
#    1211     if timeout is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:2059, in Popen._communicate(self, input, endtime, orig_timeout)
#    2052     self._check_timeout(endtime, orig_timeout,
#    2053                         stdout, stderr,
#    2054                         skip_check_and_raise=True)
#    2055     raise RuntimeError(  # Impossible :)
#    2056         '_check_timeout(..., skip_check_and_raise=True) '
#    2057         'failed to raise TimeoutExpired.')
# -> 2059 ready = selector.select(timeout)
#    2060 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2062 # XXX Rewrite these to use non-blocking I/O on the file
#    2063 # objects; they are no longer using C stdio!
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# #### Execute hybrid search. Vector and nonvector text fields are queried in parallel, results are merged, and top matches of the unified result set are returned.

# %%
# Perform a hybrid search using the search_type parameter
docs = vector_store.hybrid_search(query=query, k=3)
for doc in docs:
    print(doc.page_content)

# %% [markdown]
# ## Q&A
# We can utilize OpenAI GPT completion models + Azure Search to conversationally search for and chat about the results. (If you are using GitHub Codespaces, there will be an input prompt near the top of the screen)

# %%
# Setup rag chain
prompt_str = """You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
Question: {question} 
Context: {context} 
Answer:"""


def setup_rag_chain(vector_store):
    retriever = vector_store.as_retriever(search_type="similarity", k=3)

    prompt = ChatPromptTemplate.from_template(prompt_str)
    llm = AzureChatOpenAI(
        azure_endpoint=AZURE_OPENAI_ENDPOINT,
        openai_api_version=AZURE_OPENAI_CHAT_API_VERSION,
        azure_deployment=AZURE_OPENAI_CHAT_DEPLOYMENT_NAME,
        azure_ad_token_provider=token_provider,
        temperature=0.7,
    )

    def format_docs(docs):
        return "\n\n".join(doc.page_content for doc in docs)

    rag_chain = (
        {"context": retriever | format_docs, "question": RunnablePassthrough()}
        | prompt
        | llm
        | StrOutputParser()
    )
    return rag_chain


# Setup conversational search
def conversational_search(rag_chain, query):
    print(rag_chain.invoke(query))


rag_chain = setup_rag_chain(vector_store)
while True:
    query = input("Enter your query: ")
    if query=="":
        break
    conversational_search(rag_chain, query)
# Out:
# The total revenue for Tesco for FY 2021/22 was £61,344 million. This figure includes fuel sales and excludes VAT. The revenue for the previous year (FY 2020/21) was £57,887 million.
